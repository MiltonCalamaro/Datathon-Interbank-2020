# %%
import pandas as pd
from tqdm.notebook import tqdm 
import gc
import numpy as np

# %%
import statistics as stat
def calculate_mode(x):
    try:
        moda=stat.mode(x)
    except:
        moda=np.nan
    return moda

# %% [markdown]
# ## Load Bases

# %%
sunat_train = pd.read_csv('../data/sunat_train.csv')
rcc_train = pd.read_csv('../data/rcc_train.csv')
se_train = pd.read_csv('../data/se_train.csv', index_col = 'key_value')
y_train = pd.read_csv('../data/y_train.csv', index_col = 'key_value')

sunat_test = pd.read_csv('../data/sunat_test.csv')
rcc_test = pd.read_csv('../data/rcc_test.csv')
se_test = pd.read_csv('../data/se_test.csv', index_col = 'key_value')

# %% [markdown]
# ## Procesar RCC

# %%
rcc_test['cod_instit_financiera'].fillna(rcc_test['cod_instit_financiera'].value_counts().index[0], inplace=True)
rcc_test['PRODUCTO'].fillna(rcc_test['PRODUCTO'].value_counts().index[0], inplace=True)

# %%
dict_ = {'codmes': 'int32',
 'key_value': 'int32',
 'condicion': 'int32',
 'tipo_credito': 'int32',
 'cod_instit_financiera': 'int32',
 'PRODUCTO': 'int32',
 'RIESGO_DIRECTO': 'int32',
 'COD_CLASIFICACION_DEUDOR': 'int32'}
rcc_train = rcc_train.astype(dict_)
rcc_test = rcc_test.astype(dict_)

# %%
moda=lambda x: calculate_mode(x)
moda.__name__='mode'
agg_rcc = {'condicion':['max','min','mean','std','sum'],
           'saldo':['max','min','mean','std','sum'],
           'cod_instit_financiera':['nunique','min','max',moda],
           'PRODUCTO':['nunique','min','max',moda],
           'COD_CLASIFICACION_DEUDOR':['nunique','max','min','sum','mean','std',moda]
          }

# %%
list_rcc_train_agg = []
for n,i in enumerate(tqdm(sorted(set(rcc_train.codmes),reverse=True))):
    if n in [0,1,2,3,4,5,11]:
        for c in ['tipo_credito','RIESGO_DIRECTO','COD_CLASIFICACION_DEUDOR']:
            print(f'haciendo {c}')
            rcc_train_agg = rcc_train[rcc_train.codmes>=i].groupby(['key_value', c]).saldo.sum().unstack(level = 1, fill_value=0)
            rcc_train_agg.columns = [f'{rcc_train_agg.columns.name}_{c}_saldo_ult{n+1}meses' for c in rcc_train_agg.columns]
            list_rcc_train_agg.append(rcc_train_agg)
            gc.collect()
        for c in ['tipo_credito','RIESGO_DIRECTO','COD_CLASIFICACION_DEUDOR']:
            print(f'haciendo {c}')
            rcc_train_agg = rcc_train[rcc_train.codmes>=i].groupby(['key_value', c]).condicion.sum().unstack(level = 1, fill_value=0)
            rcc_train_agg.columns = [f'{rcc_train_agg.columns.name}_{c}_condicion_ult{n+1}meses' for c in rcc_train_agg.columns]
            list_rcc_train_agg.append(rcc_train_agg)
            gc.collect()

        print(f'haciendo agg ')
        rcc_train_agg = rcc_train[rcc_train.codmes>=i].groupby('key_value').agg(agg_rcc)
        rcc_train_agg.columns = [i+'_'+j+f'_ult{n+1}mes' for i,j in rcc_train_agg.columns]
        list_rcc_train_agg.append(rcc_train_agg)
        gc.collect()
        
rcc_train_ = pd.concat(list_rcc_train_agg, axis=1)
del rcc_train, list_rcc_train_agg
# Out:
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg

# %%
list_rcc_test_agg = []
for n,i in enumerate(tqdm(sorted(set(rcc_test.codmes),reverse=True))):
    if n in [0,1,2,3,4,5,11]:
        for c in ['tipo_credito','RIESGO_DIRECTO','COD_CLASIFICACION_DEUDOR']:
            print(f'haciendo {c}')
            rcc_test_agg = rcc_test[rcc_test.codmes>=i].groupby(['key_value', c]).saldo.sum().unstack(level = 1, fill_value=0)
            rcc_test_agg.columns = [f'{rcc_test_agg.columns.name}_{c}_saldo_ult{n+1}meses' for c in rcc_test_agg.columns]
            list_rcc_test_agg.append(rcc_test_agg)
            gc.collect()
        for c in ['tipo_credito','RIESGO_DIRECTO','COD_CLASIFICACION_DEUDOR']:
            print(f'haciendo {c}')
            rcc_test_agg = rcc_test[rcc_test.codmes>=i].groupby(['key_value', c]).condicion.sum().unstack(level = 1, fill_value=0)
            rcc_test_agg.columns = [f'{rcc_test_agg.columns.name}_{c}_condicion_ult{n+1}meses' for c in rcc_test_agg.columns]
            list_rcc_test_agg.append(rcc_test_agg)
            gc.collect()
        print(f'haciendo agg')    
        rcc_test_agg = rcc_test[rcc_test.codmes>=i].groupby('key_value').agg(agg_rcc)
        rcc_test_agg.columns = [i+'_'+j+f'_ult{n+1}mes' for i,j in rcc_test_agg.columns]
        list_rcc_test_agg.append(rcc_test_agg)
        gc.collect()

rcc_test_ = pd.concat(list_rcc_test_agg, axis=1)
del rcc_test, list_rcc_test_agg
# Out:
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg

# %%
### asegurar que las columnas esten en ambas bases (train/test)
print(rcc_train_.shape, rcc_test_.shape)
keep_columns = list(set(rcc_train_.columns).intersection(rcc_test_.columns))
rcc_train_ = rcc_train_[keep_columns].copy()
rcc_test_ = rcc_test_[keep_columns].copy()
print(rcc_train_.shape, rcc_test_.shape)

# %%
### imputar datos categoricos
var_categ = [i for i in rcc_train_.columns if 'mode' in i]
for i in var_categ:
    rcc_train_[i] = rcc_train_[i].fillna(rcc_train_[i].value_counts().index[0])
    rcc_test_[i] = rcc_test_[i].fillna(rcc_train_[i].value_counts().index[0])

# %%
### mean encoding
rcc_train_ = pd.concat([rcc_train_, y_train], axis=1)
for i in var_categ:
    me = rcc_train_.groupby([i])['target'].mean().to_dict() 
    rcc_train_[f'{i}_me'] =  rcc_train_[i].map(me) 
    rcc_test_[f'{i}_me'] =  rcc_test_[i].map(me)
    ### imputar datos faltantes
    rcc_test_[f'{i}_me'] =  rcc_test_[f'{i}_me'].fillna(rcc_train_[f'{i}_me'].median())
    
rcc_train_.drop('target', axis=1, inplace=True)
rcc_train_.drop(var_categ, axis=1, inplace=True)
rcc_test_.drop(var_categ, axis=1, inplace=True)

# %%
### imputar datos cauntitativos
var_cuanti = [i for i in rcc_train_.columns if 'std' in i]
for i in var_cuanti:
    rcc_train_[i] = rcc_train_[i].fillna(rcc_train_[i].median())
    rcc_test_[i] = rcc_test_[i].fillna(rcc_train_[i].median())

# %%
### unir RCC en la base final
train = rcc_train_.copy()
test = rcc_test_.copy()
del rcc_train_, rcc_test_

# %% [markdown]
# ## Procesar SE

# %%
dict_ = {'sexo':'int32',
         'est_cvl':'int32',
         'sit_lab':'int32',
         'cod_ocu':'int32',
         'ctd_hijos':'int32',
         'flg_sin_email':'int32',
         'ctd_veh':'int32',
         'lgr_vot':'int32',
         'prv':'int32',
         'dto':'int32',
         'rgn':'int32',
         'tip_lvledu':'int32'}
se_train = se_train.astype(dict_)
se_test = se_test.astype(dict_)

# %%
### imputar datos faltantes en la base se_[train/test]
se_train['edad'].fillna(se_train['edad'].median(), inplace=True)
se_test['edad'].fillna(se_train['edad'].median(), inplace=True)
se_train['cod_ubi'].fillna(se_train['cod_ubi'].median(), inplace=True)
se_test['cod_ubi'].fillna(se_train['cod_ubi'].median(), inplace=True)

# %%
### mean encoding
var_categ=['sit_lab','lgr_vot','sexo','rgn','tip_lvledu','flg_sin_email','prv','est_cvl','cod_ocu','dto']
# var_caunti=['edad','ctd_hijos','ctd_veh','cod_ubi']
se_train['target'] = y_train.loc[se_train.index]
for i in var_categ:
    me = se_train.groupby([i])['target'].mean().to_dict() 
    se_train[f'{i}_me'] =  se_train[i].map(me) 
    se_test[f'{i}_me'] =  se_test[i].map(me)
    ### imputar datos faltantes
    se_test[f'{i}_me'] =  se_test[f'{i}_me'].fillna(se_train[f'{i}_me'].median())
se_train.drop('target', axis=1, inplace=True)
se_train.drop(var_categ, axis=1, inplace=True)
se_test.drop(var_categ, axis=1, inplace=True)

# %%
### unir SE en la base final
train = train.join(se_train) 
test = test.join(se_test)
del se_train, se_test

# %%
### imputar valores faltantes
var_caunti = ['lgr_vot_me','sit_lab_me','cod_ubi','tip_lvledu_me','prv_me','rgn_me',
 'ctd_hijos','edad','cod_ocu_me','ctd_veh','est_cvl_me','dto_me','flg_sin_email_me','sexo_me']
for i in var_caunti:
    train[i] = train[i].fillna(train[i].median())
    test[i] = test[i].fillna(train[i].median())

# %% [markdown]
# ## Procesar SUNAT

# %%
### eliminar registros duplicados
sunat_train.drop_duplicates(inplace=True)
sunat_test.drop_duplicates(inplace=True)
sunat_train.shape, sunat_test.shape

# %%
#### eliminando registros con fecalta y fecbaja con valores nulos
mask = ~((sunat_train['fecalta'].astype('str')=='nan') & (sunat_train['fecbaja'].astype('str')=='nan'))
sunat_train = sunat_train[mask].copy()
mask = ~((sunat_test['fecalta'].astype('str')=='nan') & (sunat_test['fecbaja'].astype('str')=='nan'))
sunat_test = sunat_test[mask].copy()
sunat_train.shape, sunat_test.shape

# %%
dict_ = {'tipcontribuyente': 'int32',
         'tippersona': 'int32',
         'ciiu': 'int32',
         'ubigeo': 'int32',
         'condiciondomicilio': 'int32',
         'estadocontribuyente': 'int32',
         'codvia': 'int32',
         'codzona': 'int32',
         'contabilidad': 'int32',
         'facturacion': 'int32',
         'domiciliado': 'int32',
         'comercioexterior': 'int32',
         'cargorele': 'int32',
         'codentidadtributo': 'int32',
         'estadotributo': 'int32'}
sunat_train = sunat_train.astype(dict_)
sunat_test = sunat_test.astype(dict_)

# %%
moda=lambda x: calculate_mode(x)
moda.__name__='mode'
agg_sunat = {'tipcontribuyente':['nunique',moda],
           'tippersona':['nunique',moda],
           'ciiu':['nunique', moda],
           'ubigeo':['nunique',moda],
           'condiciondomicilio':['nunique',moda],
           'estadocontribuyente':['nunique',moda],
           'codvia':['nunique',moda],
           'codzona':['nunique',moda],
           'contabilidad':['nunique',moda],
           'facturacion':['nunique',moda],
           'domiciliado':['nunique',moda],
           'comercioexterior':['nunique',moda],
           'cargorele':['nunique',moda],
           'codentidadtributo':['nunique',moda],
           'estadotributo':['nunique',moda],
           'fecalta':['mean'],
#            'fecbaja':['mean'],
            }

sunat_train_ = sunat_train.groupby('key_value').agg(agg_sunat)
sunat_train_.columns = [i+'_'+j for i,j in sunat_train_.columns]
sunat_test_ = sunat_test.groupby('key_value').agg(agg_sunat)
sunat_test_.columns = [i+'_'+j for i,j in sunat_test_.columns]
del sunat_train, sunat_test

# %%
### imputar datos categoricos
var_categ = [i for i in sunat_train_.columns if 'mode' in i]
for i in var_categ:
    sunat_train_[i] = sunat_train_[i].fillna(sunat_train_[i].value_counts().index[0])
    sunat_test_[i] = sunat_test_[i].fillna(sunat_train_[i].value_counts().index[0])

# %%
### unir SUNAT en la base final
train = train.join(sunat_train_)
test = test.join(sunat_test_)
del sunat_train_, sunat_test_

# %%
test.isna().sum().sort_values().tail(32)/len(test)

# %%
var_aux = list(train.isna().sum().sort_values().tail(31).index)
var_categ = [i for i in var_aux if 'mode' in i]
var_cuanti = [i for i in var_aux if 'mode' not in i]
len(var_aux), len(var_categ), len(var_cuanti)

# %%
for i in var_cuanti:
    train[i] = train[i].fillna(train[i].median())
    test[i] = test[i].fillna(train[i].median())
for i in var_categ:
    train[i] = train[i].fillna(train[i].value_counts().index[0])
    test[i] = test[i].fillna(train[i].value_counts().index[0])

# %% [markdown]
# ## Training

# %%
test.isna().sum().sort_values()

# %%
train.shape, test.shape

# %%
features_importances = list(np.load('feature_importances.npy'))
train = train[features_importances].copy()
test = test[features_importances].copy()

# %%
from catboost import CatBoostClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
import numpy as np
folds = [train.index[t] for t, v in KFold(5).split(train)]
test_probs = []
train_probs = []
fi = []
for i, idx in enumerate(folds):
    print("*"*10, i, "*"*10)
    Xt = train.loc[idx]
    yt = y_train.loc[Xt.index]

    Xv = train.drop(Xt.index)
    yv = y_train.loc[Xv.index]

    learner = CatBoostClassifier(n_estimators=1000,  eval_metric = 'AUC', max_depth = 6)
    learner.fit(Xt, yt,  early_stopping_rounds=10, 
                eval_set=[(Xt, yt), (Xv, yv)], verbose=50)
    test_probs.append(pd.Series(learner.predict_proba(test)[:, -1], index=test.index, name="fold_" + str(i)))
    train_probs.append(pd.Series(learner.predict_proba(Xv)[:, -1], index=Xv.index, name="probs"))
    fi.append(pd.Series(learner.feature_importances_ / learner.feature_importances_.sum(), index=Xt.columns))
    gc.collect()
test_probs = pd.concat(test_probs, axis=1).mean(axis=1)
train_probs = pd.concat(train_probs)
fi = pd.concat(fi, axis=1).mean(axis=1)
print("*" * 21)
print("roc auc estimado: ", roc_auc_score(y_train, train_probs.loc[y_train.index]))
print("roc auc varianza: ", np.std([roc_auc_score(y_train.loc[folds[i]], train_probs.iloc[folds[i]]) for i in range(len(folds))]))
# Out:
# ********** 0 **********
# Learning rate set to 0.128212
# 0:	test: 0.7509755	test1: 0.7516604	best: 0.7516604 (0)	total: 400ms	remaining: 6m 39s
# 50:	test: 0.8281053	test1: 0.8261694	best: 0.8261694 (50)	total: 15.8s	remaining: 4m 53s
# 100:	test: 0.8376401	test1: 0.8343095	best: 0.8343095 (100)	total: 30.2s	remaining: 4m 28s
# 150:	test: 0.8445233	test1: 0.8392620	best: 0.8392620 (150)	total: 44.7s	remaining: 4m 11s
# 200:	test: 0.8493130	test1: 0.8416827	best: 0.8416827 (200)	total: 58.4s	remaining: 3m 52s
# 250:	test: 0.8531661	test1: 0.8431477	best: 0.8431477 (250)	total: 1m 11s	remaining: 3m 34s
# 300:	test: 0.8567614	test1: 0.8443314	best: 0.8443334 (298)	total: 1m 25s	remaining: 3m 18s
# 350:	test: 0.8596784	test1: 0.8452470	best: 0.8452470 (350)	total: 1m 39s	remaining: 3m 3s
# 400:	test: 0.8623386	test1: 0.8459249	best: 0.8459249 (400)	total: 1m 52s	remaining: 2m 48s
# 450:	test: 0.8649366	test1: 0.8464176	best: 0.8464176 (450)	total: 2m 6s	remaining: 2m 33s
# 500:	test: 0.8675241	test1: 0.8469403	best: 0.8469403 (500)	total: 2m 19s	remaining: 2m 19s
# 550:	test: 0.8699380	test1: 0.8473404	best: 0.8473404 (550)	total: 2m 33s	remaining: 2m 5s
# 600:	test: 0.8722663	test1: 0.8476482	best: 0.8476578 (596)	total: 2m 47s	remaining: 1m 51s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.8476817977
# bestIteration = 601
#
# Shrink model to first 602 iterations.
# ********** 1 **********
# Learning rate set to 0.128212
# 0:	test: 0.7518550	test1: 0.7505605	best: 0.7505605 (0)	total: 317ms	remaining: 5m 16s
# 50:	test: 0.8289604	test1: 0.8261115	best: 0.8261115 (50)	total: 15.6s	remaining: 4m 50s
# 100:	test: 0.8382538	test1: 0.8337082	best: 0.8337082 (100)	total: 30s	remaining: 4m 27s
# 150:	test: 0.8449258	test1: 0.8377256	best: 0.8377256 (150)	total: 44.1s	remaining: 4m 7s
# 200:	test: 0.8496686	test1: 0.8399481	best: 0.8399481 (200)	total: 58.3s	remaining: 3m 51s
# 250:	test: 0.8536806	test1: 0.8414206	best: 0.8414206 (250)	total: 1m 11s	remaining: 3m 34s
# 300:	test: 0.8569586	test1: 0.8424452	best: 0.8424452 (300)	total: 1m 25s	remaining: 3m 17s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.8431508919
# bestIteration = 336
#
# Shrink model to first 337 iterations.
# ********** 2 **********
# Learning rate set to 0.128212
# 0:	test: 0.7505374	test1: 0.7532182	best: 0.7532182 (0)	total: 314ms	remaining: 5m 13s
# 50:	test: 0.8285420	test1: 0.8299023	best: 0.8299023 (50)	total: 15.5s	remaining: 4m 48s
# 100:	test: 0.8373416	test1: 0.8363235	best: 0.8363235 (100)	total: 29.9s	remaining: 4m 25s
# 150:	test: 0.8442197	test1: 0.8408919	best: 0.8408919 (150)	total: 44.3s	remaining: 4m 9s
# 200:	test: 0.8489027	test1: 0.8433634	best: 0.8433634 (200)	total: 57.9s	remaining: 3m 49s
# 250:	test: 0.8531495	test1: 0.8451735	best: 0.8451735 (250)	total: 1m 11s	remaining: 3m 33s
# 300:	test: 0.8565847	test1: 0.8467170	best: 0.8467251 (299)	total: 1m 25s	remaining: 3m 18s
# 350:	test: 0.8595228	test1: 0.8472772	best: 0.8472772 (350)	total: 1m 39s	remaining: 3m 3s
# 400:	test: 0.8623826	test1: 0.8477885	best: 0.8477885 (400)	total: 1m 52s	remaining: 2m 48s
# 450:	test: 0.8650485	test1: 0.8485017	best: 0.8485029 (449)	total: 2m 6s	remaining: 2m 33s
# 500:	test: 0.8675597	test1: 0.8489801	best: 0.8490160 (499)	total: 2m 20s	remaining: 2m 19s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.8490226234
# bestIteration = 502
#
# Shrink model to first 503 iterations.
# ********** 3 **********
# Learning rate set to 0.128212
# 0:	test: 0.7507861	test1: 0.7527755	best: 0.7527755 (0)	total: 318ms	remaining: 5m 17s
# 50:	test: 0.8287249	test1: 0.8284810	best: 0.8284810 (50)	total: 15.5s	remaining: 4m 48s
# 100:	test: 0.8376741	test1: 0.8355178	best: 0.8355178 (100)	total: 29.9s	remaining: 4m 25s
# 150:	test: 0.8441867	test1: 0.8397428	best: 0.8397428 (150)	total: 43.8s	remaining: 4m 6s
# 200:	test: 0.8492675	test1: 0.8422705	best: 0.8422815 (199)	total: 58s	remaining: 3m 50s
# 250:	test: 0.8529150	test1: 0.8437629	best: 0.8437629 (250)	total: 1m 11s	remaining: 3m 32s
# 300:	test: 0.8563123	test1: 0.8449212	best: 0.8449278 (293)	total: 1m 25s	remaining: 3m 18s
# 350:	test: 0.8591190	test1: 0.8458037	best: 0.8458037 (350)	total: 1m 38s	remaining: 3m 2s
# 400:	test: 0.8622121	test1: 0.8467599	best: 0.8467599 (400)	total: 1m 52s	remaining: 2m 47s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.8468295577
# bestIteration = 403
#
# Shrink model to first 404 iterations.
# ********** 4 **********
# Learning rate set to 0.128212
# 0:	test: 0.7526280	test1: 0.7473082	best: 0.7473082 (0)	total: 319ms	remaining: 5m 18s
# 50:	test: 0.8305893	test1: 0.8207538	best: 0.8207538 (50)	total: 15.6s	remaining: 4m 50s
# 100:	test: 0.8395635	test1: 0.8280775	best: 0.8280775 (100)	total: 29.9s	remaining: 4m 26s
# 150:	test: 0.8462633	test1: 0.8323961	best: 0.8323961 (150)	total: 44.2s	remaining: 4m 8s
# 200:	test: 0.8515946	test1: 0.8350246	best: 0.8350246 (200)	total: 58.5s	remaining: 3m 52s
# 250:	test: 0.8557452	test1: 0.8365634	best: 0.8365634 (250)	total: 1m 12s	remaining: 3m 36s
# 300:	test: 0.8588662	test1: 0.8374724	best: 0.8374789 (298)	total: 1m 26s	remaining: 3m 20s
# 350:	test: 0.8617084	test1: 0.8381403	best: 0.8381403 (350)	total: 1m 40s	remaining: 3m 4s
# 400:	test: 0.8644170	test1: 0.8387757	best: 0.8387757 (400)	total: 1m 53s	remaining: 2m 49s
# 450:	test: 0.8669531	test1: 0.8393126	best: 0.8393164 (449)	total: 2m 6s	remaining: 2m 34s
# 500:	test: 0.8694840	test1: 0.8396836	best: 0.8396836 (500)	total: 2m 20s	remaining: 2m 19s
# 550:	test: 0.8719400	test1: 0.8400973	best: 0.8401067 (549)	total: 2m 33s	remaining: 2m 5s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.8403596806
# bestIteration = 567
#
# Shrink model to first 568 iterations.
# *********************
# roc auc estimado:  0.8454291196957264
# roc auc varianza:  0.0007904768077827976

# %%
fi.sort_values(ascending=False).head(50)
# Out:
# dto_me                                            0.055438
# COD_CLASIFICACION_DEUDOR_mean_ult1mes             0.030023
# tip_lvledu_me                                     0.026721
# COD_CLASIFICACION_DEUDOR_sum_ult1mes              0.024730
# cod_instit_financiera_mode_ult1mes_me             0.023280
# RIESGO_DIRECTO_1_saldo_ult1meses                  0.019354
# cod_instit_financiera_mode_ult5mes_me             0.019231
# edad                                              0.019082
# tipo_credito_11_saldo_ult1meses                   0.019059
# RIESGO_DIRECTO_-1_saldo_ult12meses                0.016292
# tipo_credito_11_saldo_ult12meses                  0.014433
# cod_instit_financiera_mode_ult12mes_me            0.013646
# flg_sin_email_me                                  0.013404
# sexo_me                                           0.013054
# saldo_sum_ult1mes                                 0.012736
# RIESGO_DIRECTO_1_condicion_ult2meses              0.012512
# RIESGO_DIRECTO_1_saldo_ult12meses                 0.011903
# tipo_credito_12_saldo_ult2meses                   0.011854
# COD_CLASIFICACION_DEUDOR_nunique_ult1mes          0.011386
# cod_instit_financiera_max_ult1mes                 0.011273
# RIESGO_DIRECTO_-1_saldo_ult2meses                 0.011227
# saldo_mean_ult12mes                               0.011155
# sit_lab_me                                        0.010869
# saldo_mean_ult1mes                                0.010299
# COD_CLASIFICACION_DEUDOR_0_saldo_ult12meses       0.010170
# cod_instit_financiera_nunique_ult1mes             0.010006
# COD_CLASIFICACION_DEUDOR_0_saldo_ult1meses        0.009602
# RIESGO_DIRECTO_-1_saldo_ult1meses                 0.009584
# condicion_std_ult1mes                             0.009326
# PRODUCTO_min_ult1mes                              0.009022
# cod_instit_financiera_min_ult1mes                 0.008731
# RIESGO_DIRECTO_1_saldo_ult2meses                  0.008582
# saldo_sum_ult12mes                                0.008144
# COD_CLASIFICACION_DEUDOR_std_ult2mes              0.007782
# COD_CLASIFICACION_DEUDOR_5_condicion_ult1meses    0.007735
# cod_ubi                                           0.007126
# cod_instit_financiera_max_ult2mes                 0.007064
# saldo_min_ult1mes                                 0.007021
# saldo_mean_ult2mes                                0.006953
# COD_CLASIFICACION_DEUDOR_max_ult1mes              0.006785
# PRODUCTO_min_ult4mes                              0.006558
# ctd_veh                                           0.006256
# prv_me                                            0.006233
# condicion_sum_ult1mes                             0.005887
# cod_instit_financiera_mode_ult6mes_me             0.005655
# cod_instit_financiera_max_ult12mes                0.005641
# RIESGO_DIRECTO_1_condicion_ult12meses             0.005412
# lgr_vot_me                                        0.005410
# tipo_credito_12_saldo_ult1meses                   0.005320
# PRODUCTO_max_ult1mes                              0.005306
# dtype: float64

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
import numpy as np
folds = [train.index[t] for t, v in KFold(5).split(train)]
test_probs = []
train_probs = []
fi = []
for i, idx in enumerate(folds):
    print("*"*10, i, "*"*10)
    Xt = train.loc[idx]
    yt = y_train.loc[Xt.index]

    Xv = train.drop(Xt.index)
    yv = y_train.loc[Xv.index]

    learner = LGBMClassifier(n_estimators=1000, max_depth = 6, boosting_type='gbdt', min_child_samples=1000)
    learner.fit(Xt, yt,  early_stopping_rounds=10, eval_metric="auc",
                eval_set=[(Xt, yt), (Xv, yv)], verbose=50)
    test_probs.append(pd.Series(learner.predict_proba(test)[:, -1], index=test.index, name="fold_" + str(i)))
    train_probs.append(pd.Series(learner.predict_proba(Xv)[:, -1], index=Xv.index, name="probs"))
    fi.append(pd.Series(learner.feature_importances_ / learner.feature_importances_.sum(), index=Xt.columns))

test_probs = pd.concat(test_probs, axis=1).mean(axis=1)
train_probs = pd.concat(train_probs)
fi = pd.concat(fi, axis=1).mean(axis=1)
print("*" * 21)
print("roc auc estimado: ", roc_auc_score(y_train, train_probs.loc[y_train.index]))
print("roc auc varianza: ", np.std([roc_auc_score(y_train.loc[folds[i]], train_probs.iloc[folds[i]]) for i in range(len(folds))]))

# %%
fi.sort_values(ascending=False).head(50)
# Out:
# dto_me                                            0.028112
# edad                                              0.021967
# saldo_mean_ult12mes                               0.020638
# cod_ubi                                           0.017719
# RIESGO_DIRECTO_-1_saldo_ult12meses                0.017402
# RIESGO_DIRECTO_1_saldo_ult1meses                  0.017250
# tipo_credito_11_saldo_ult1meses                   0.015838
# RIESGO_DIRECTO_1_saldo_ult12meses                 0.015215
# tipo_credito_11_saldo_ult12meses                  0.014024
# cod_instit_financiera_max_ult1mes                 0.013429
# cod_instit_financiera_mode_ult12mes_me            0.013347
# RIESGO_DIRECTO_-1_saldo_ult1meses                 0.013110
# saldo_min_ult1mes                                 0.012862
# cod_instit_financiera_mode_ult1mes_me             0.012132
# tipo_credito_12_saldo_ult12meses                  0.011808
# COD_CLASIFICACION_DEUDOR_0_saldo_ult12meses       0.011468
# saldo_mean_ult1mes                                0.011082
# fecalta_mean                                      0.010778
# tip_lvledu_me                                     0.010564
# tipo_credito_12_saldo_ult1meses                   0.010240
# cod_instit_financiera_min_ult1mes                 0.009916
# RIESGO_DIRECTO_1_saldo_ult2meses                  0.009434
# prv_me                                            0.009317
# ubigeo_mode                                       0.009301
# saldo_max_ult12mes                                0.009103
# saldo_max_ult1mes                                 0.008832
# PRODUCTO_max_ult1mes                              0.008116
# saldo_std_ult1mes                                 0.008002
# cod_instit_financiera_max_ult12mes                0.007893
# ciiu_mode                                         0.007838
# RIESGO_DIRECTO_-1_saldo_ult2meses                 0.007653
# cod_instit_financiera_min_ult12mes                0.007575
# lgr_vot_me                                        0.007526
# RIESGO_DIRECTO_1_saldo_ult3meses                  0.007392
# sexo_me                                           0.007236
# flg_sin_email_me                                  0.007231
# saldo_std_ult12mes                                0.007163
# saldo_sum_ult1mes                                 0.007148
# cod_ocu_me                                        0.007129
# saldo_sum_ult12mes                                0.007013
# RIESGO_DIRECTO_1_condicion_ult12meses             0.006685
# COD_CLASIFICACION_DEUDOR_0_saldo_ult1meses        0.006377
# tipo_credito_10_saldo_ult12meses                  0.006254
# COD_CLASIFICACION_DEUDOR_5_condicion_ult1meses    0.006241
# saldo_mean_ult2mes                                0.006129
# sit_lab_me                                        0.005992
# PRODUCTO_nunique_ult1mes                          0.005887
# RIESGO_DIRECTO_1_saldo_ult6meses                  0.005527
# saldo_min_ult2mes                                 0.005492
# estadocontribuyente_mode                          0.005353
# dtype: float64

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
def get_roc_auc(X, y):
    folds = [X.index[t] for t, v in KFold(5).split(X)]
    Xt = X.loc[folds[4]]
    yt = y.loc[Xt.index]

    Xv = X.drop(Xt.index)
    yv = y.loc[Xv.index]
    learner = LGBMClassifier(n_estimators=1000, max_depth = 6, boosting_type='gbdt', min_child_samples=1000)
    learner.fit(Xt, yt,  early_stopping_rounds=10, eval_metric="auc",
    eval_set=[(Xt, yt), (Xv, yv)], verbose=600)
    probs = learner.predict_proba(Xv)[:, -1] 
    print(f'roc auc estimado de: {roc_auc_score(yv, probs)}')
    
import pandas as pd
import numpy as np
import statsmodels.api as sm

def stepwise_selection(X, y, 
                       initial_list=[], 
                       threshold_in=0.01, 
                       threshold_out = 0.05, 
                       verbose=True):
    included = list(initial_list)
    while True:
        changed=False
        # forward step
        excluded = list(set(X.columns)-set(included))
        new_pval = pd.Series(index=excluded)
        for new_column in excluded:
            model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included+[new_column]]))).fit()
            new_pval[new_column] = model.pvalues[new_column]
        best_pval = new_pval.min()
        if best_pval < threshold_in:
            best_feature = excluded[new_pval.argmin()]
            included.append(best_feature)
            changed=True
            if verbose:
                print('#'*25)
                print('Add  {:30} with p-value {:.6}'.format(best_feature, best_pval))
                get_roc_auc(X[included], y)
        # backward step
        model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included]))).fit()
        # use all coefs except intercept
        pvalues = model.pvalues.iloc[1:]
        worst_pval = pvalues.max() # null if pvalues is empty
        if worst_pval > threshold_out:
            changed=True
            worst_feature = included[pvalues.argmax()]
            included.remove(worst_feature)
            if verbose:
                print('Drop {:30} with p-value {:.6}'.format(worst_feature, worst_pval))
        if not changed:
            break
        gc.collect()
    return included

initial_list = list(fi.sort_values().head(350).index)
result = stepwise_selection(train, y_train.target, initial_list=initial_list)

print('resulting features:')
print(result)

# %%
# Drop cod_instit_financiera_nunique_ult3mes with p-value 0.963468

# %%
from catboost import CatBoostClassifier
learner_catboost = CatBoostClassifier(n_estimators=1000, eval_metric = 'AUC', max_depth = 6)
learner_catboost.fit(train, y_train,  early_stopping_rounds=10, verbose = 50)
# Out:
# Learning rate set to 0.126968
# 0:	total: 350ms	remaining: 5m 49s
# 50:	total: 16.9s	remaining: 5m 13s
# 100:	total: 32.3s	remaining: 4m 47s
# 150:	total: 47.6s	remaining: 4m 27s
# 200:	total: 1m 2s	remaining: 4m 9s
# 250:	total: 1m 17s	remaining: 3m 52s
# 300:	total: 1m 32s	remaining: 3m 35s
# 350:	total: 1m 48s	remaining: 3m 21s
# 400:	total: 2m 4s	remaining: 3m 5s
# 450:	total: 2m 18s	remaining: 2m 48s
# 500:	total: 2m 33s	remaining: 2m 32s
# 550:	total: 2m 48s	remaining: 2m 17s
# 600:	total: 3m 3s	remaining: 2m 1s
# 650:	total: 3m 18s	remaining: 1m 46s
# 700:	total: 3m 32s	remaining: 1m 30s
# 750:	total: 3m 47s	remaining: 1m 15s
# 800:	total: 4m 2s	remaining: 1m
# 850:	total: 4m 16s	remaining: 44.9s
# 900:	total: 4m 31s	remaining: 29.8s
# 950:	total: 4m 46s	remaining: 14.8s
# 999:	total: 5m 1s	remaining: 0us

# %%
from lightgbm import LGBMClassifier
learner_lightgbm = LGBMClassifier(n_estimators=1000, max_depth=6, boosting_type='gbdt', min_child_samples=1000)
learner_lightgbm.fit(train, y_train, eval_metric="auc", verbose=50)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# LGBMClassifier(max_depth=6, min_child_samples=1000, n_estimators=1000)

# %%
test_probs_catboost = pd.Series(learner_catboost.predict_proba(test)[:, -1], index=test.index, name="target")
test_probs_lightgbm = pd.Series(learner_lightgbm.predict_proba(test)[:, -1], index=test.index, name="target")
test_probs_mean = test_probs_catboost*0.5 + test_probs_lightgbm*0.5
test_probs_mean.name = 'target'
test_probs_mean.shape
# Out:
# (396666,)

# %%
test_probs_mean.to_csv("../results/test52.csv")

# %%
mkdir /root/.kaggle/

# %%
cp ../kaggle.json /root/.kaggle/

# %%
# !kaggle competitions submit -c interbank20 -f ../results/test52.csv -m "test52"
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# 100%|██████████████████████████████████████| 10.1M/10.1M [00:02<00:00, 3.62MB/s]
# Successfully submitted to Datathon Internacional Interbank 2020

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

def stepwise_selection(X, y, 
                       initial_list=[], 
                       threshold_in=0.01, 
                       threshold_out = 0.05, 
                       verbose=True):
    """ Perform a forward-backward feature selection 
    based on p-value from statsmodels.api.OLS
    Arguments:
        X - pandas.DataFrame with candidate features
        y - list-like with the target
        initial_list - list of features to start with (column names of X)
        threshold_in - include a feature if its p-value < threshold_in
        threshold_out - exclude a feature if its p-value > threshold_out
        verbose - whether to print the sequence of inclusions and exclusions
    Returns: list of selected features 
    Always set threshold_in < threshold_out to avoid infinite looping.
    See https://en.wikipedia.org/wiki/Stepwise_regression for the details
    """
    included = list(initial_list)
    while True:
        changed=False
        # forward step
        excluded = list(set(X.columns)-set(included))
        new_pval = pd.Series(index=excluded)
        for new_column in excluded:
            model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included+[new_column]]))).fit()
            new_pval[new_column] = model.pvalues[new_column]
        best_pval = new_pval.min()
        if best_pval < threshold_in:
            best_feature = excluded[new_pval.argmin()]
            included.append(best_feature)
            changed=True
            if verbose:
                print('Add  {:30} with p-value {:.6}'.format(best_feature, best_pval))

        # backward step
        model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included]))).fit()
        # use all coefs except intercept
        pvalues = model.pvalues.iloc[1:]
        worst_pval = pvalues.max() # null if pvalues is empty
        if worst_pval > threshold_out:
            changed=True
            worst_feature = included[pvalues.argmax()]
            included.remove(worst_feature)
            if verbose:
                print('Drop {:30} with p-value {:.6}'.format(worst_feature, worst_pval))
        if not changed:
            break
        gc.collect()
    return included

initial_list = ['PRODUCTO_nunique_ult1mes', 'COD_CLASIFICACION_DEUDOR_sum_ult12mes', 'saldo_mean_ult12mes',
                'COD_CLASIFICACION_DEUDOR_4_condicion_ult2meses', 'COD_CLASIFICACION_DEUDOR_mean_ult1mes', 
                'PRODUCTO_min_ult1mes', 'RIESGO_DIRECTO_1_condicion_ult12meses', 'PRODUCTO_mode_ult1mes_me', 
                'cod_instit_financiera_mode_ult1mes_me', 'tipo_credito_11_saldo_ult2meses', 'edad', 
                'tipo_credito_11_saldo_ult12meses', 'COD_CLASIFICACION_DEUDOR_mode_ult1mes_me',
                'RIESGO_DIRECTO_1_condicion_ult1meses', 'PRODUCTO_nunique_ult3mes', 'RIESGO_DIRECTO_1_saldo_ult4meses',
                'cod_instit_financiera_mode_ult2mes_me', 'cod_instit_financiera_min_ult1mes', 'estadotributo_mode',
                'cod_ocu_me', 'ciiu_mode', 'sit_lab_me', 'COD_CLASIFICACION_DEUDOR_nunique_ult1mes', 
                'tipo_credito_11_saldo_ult3meses', 'COD_CLASIFICACION_DEUDOR_max_ult1mes', 'tipo_credito_10_saldo_ult2meses',
                'cod_instit_financiera_nunique_ult1mes', 'sexo_me', 'prv_me', 'PRODUCTO_max_ult12mes', 'RIESGO_DIRECTO_1_saldo_ult1meses',
                'cod_instit_financiera_max_ult1mes', 'cod_instit_financiera_mode_ult12mes_me', 'tip_lvledu_me', 'condicion_max_ult6mes',
                'cod_ubi', 'COD_CLASIFICACION_DEUDOR_std_ult2mes', 'ctd_veh', 'dto_me', 'COD_CLASIFICACION_DEUDOR_std_ult12mes',
                'COD_CLASIFICACION_DEUDOR_nunique_ult2mes', 'PRODUCTO_min_ult12mes', 'flg_sin_email_me',
                'tipo_credito_11_saldo_ult1meses','COD_CLASIFICACION_DEUDOR_std_ult1mes','cod_instit_financiera_min_ult12mes',
                'est_cvl_me','estadocontribuyente_mode','COD_CLASIFICACION_DEUDOR_nunique_ult6mes','condicion_std_ult1mes',         
                'condicion_std_ult2mes','COD_CLASIFICACION_DEUDOR_max_ult2mes','COD_CLASIFICACION_DEUDOR_3_condicion_ult1meses', 
                'PRODUCTO_nunique_ult12mes','PRODUCTO_max_ult4mes','tippersona_nunique','estadotributo_nunique',         
                'codentidadtributo_nunique','cod_instit_financiera_nunique_ult2mes','rgn_me','tipo_credito_12_saldo_ult4meses', 
                'tipo_credito_12_saldo_ult12meses','tipo_credito_99_saldo_ult12meses']

# result = stepwise_selection(train, y_train.target, initial_list=initial_list)

# print('resulting features:')
# print(result)

# %%
import pandas as pd
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
folds = [train.index[t] for t, v in KFold(5).split(train)]

def stepwise_selection(X, y, 
                       initial_list=[], 
                       threshold_in=0.01, 
                       threshold_out = 0.05, 
                       verbose=True):
    included = list(initial_list)
    score_roc_auc = 0
    while True:
        changed=False
        # forward step
        excluded = list(set(X.columns)-set(included))
        new_roc_auc = pd.Series(index=excluded)
        for new_column in excluded:
            Xt = X.loc[folds[4],included+[new_column]]
            yt = y.loc[Xt.index]

            Xv = X.drop(Xt.index)[included+[new_column]]
            yv = y.loc[Xv.index]
            print('#'*20)
            print(f'Test with {new_column}')
            learner = LGBMClassifier(n_estimators=1000, max_depth = 6, boosting_type='gbdt', min_child_samples=1000)
            learner.fit(Xt, yt,  early_stopping_rounds=10, eval_metric="auc",
            eval_set=[(Xt, yt), (Xv, yv)], verbose=600)

            probs = learner.predict_proba(Xv)[:, -1] 
            new_roc_auc[new_column] = roc_auc_score(yv, probs)
        best_roc_auc = new_roc_auc.min()
        if best_roc_auc > score_roc_auc:
            score_roc_auc = best_roc_auc
            best_feature = excluded[new_roc_auc.argmin()]
            included.append(best_feature)
            changed=True
            if verbose:
                print('Add  {:30} with roc-auc {:.6}'.format(best_feature, best_roc_auc))

        # backward step
        fi = pd.Series(learner.feature_importances_ / learner.feature_importances_.sum(), index=Xt.columns)
        # use all coefs except intercept
        zero_importances = list(fi[fi==0].index)
        
        if zero_importances:
            changed=True
            included = list(set(included) - set(zero_importances))
            if verbose:
                print('Drop {:30} with zero importance'.format(zero_importances))
        if not changed:
            break
        gc.collect()
    return included
initial_list = ['PRODUCTO_nunique_ult1mes', 'COD_CLASIFICACION_DEUDOR_sum_ult12mes', 'saldo_mean_ult12mes',
                'COD_CLASIFICACION_DEUDOR_4_condicion_ult2meses', 'COD_CLASIFICACION_DEUDOR_mean_ult1mes', 
                'PRODUCTO_min_ult1mes', 'RIESGO_DIRECTO_1_condicion_ult12meses', 'PRODUCTO_mode_ult1mes_me', 
                'cod_instit_financiera_mode_ult1mes_me', 'tipo_credito_11_saldo_ult2meses', 'edad', 
                'tipo_credito_11_saldo_ult12meses', 'COD_CLASIFICACION_DEUDOR_mode_ult1mes_me',
                'RIESGO_DIRECTO_1_condicion_ult1meses', 'PRODUCTO_nunique_ult3mes', 'RIESGO_DIRECTO_1_saldo_ult4meses',
                'cod_instit_financiera_mode_ult2mes_me', 'cod_instit_financiera_min_ult1mes', 'estadotributo_mode',
                'cod_ocu_me', 'ciiu_mode', 'sit_lab_me', 'COD_CLASIFICACION_DEUDOR_nunique_ult1mes', 
                'tipo_credito_11_saldo_ult3meses', 'COD_CLASIFICACION_DEUDOR_max_ult1mes', 'tipo_credito_10_saldo_ult2meses',
                'cod_instit_financiera_nunique_ult1mes', 'sexo_me', 'prv_me', 'PRODUCTO_max_ult12mes', 'RIESGO_DIRECTO_1_saldo_ult1meses',
                'cod_instit_financiera_max_ult1mes', 'cod_instit_financiera_mode_ult12mes_me', 'tip_lvledu_me', 'condicion_max_ult6mes',
                'cod_ubi', 'COD_CLASIFICACION_DEUDOR_std_ult2mes', 'ctd_veh', 'dto_me', 'COD_CLASIFICACION_DEUDOR_std_ult12mes',
                'COD_CLASIFICACION_DEUDOR_nunique_ult2mes', 'PRODUCTO_min_ult12mes', 'flg_sin_email_me',
                'tipo_credito_11_saldo_ult1meses','COD_CLASIFICACION_DEUDOR_std_ult1mes','cod_instit_financiera_min_ult12mes',
                'est_cvl_me','estadocontribuyente_mode','COD_CLASIFICACION_DEUDOR_nunique_ult6mes','condicion_std_ult1mes',         
                'condicion_std_ult2mes','COD_CLASIFICACION_DEUDOR_max_ult2mes','COD_CLASIFICACION_DEUDOR_3_condicion_ult1meses', 
                'PRODUCTO_nunique_ult12mes','PRODUCTO_max_ult4mes','tippersona_nunique','estadotributo_nunique',         
                'codentidadtributo_nunique','cod_instit_financiera_nunique_ult2mes','rgn_me','tipo_credito_12_saldo_ult4meses', 
                'tipo_credito_12_saldo_ult12meses','tipo_credito_99_saldo_ult12meses']

result = stepwise_selection(train, y_train.target, initial_list=initial_list)

print('resulting features:')
print(result)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# ####################
# Test with domiciliado_nunique
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [483]	training's auc: 0.870626	training's binary_logloss: 0.281484	valid_1's auc: 0.838575	valid_1's binary_logloss: 0.301456
# ####################
# Test with RIESGO_DIRECTO_1_condicion_ult3meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [430]	training's auc: 0.868355	training's binary_logloss: 0.283352	valid_1's auc: 0.838593	valid_1's binary_logloss: 0.301507
# ####################
# Test with COD_CLASIFICACION_DEUDOR_5_saldo_ult5meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [458]	training's auc: 0.869396	training's binary_logloss: 0.282481	valid_1's auc: 0.837986	valid_1's binary_logloss: 0.301844
# ####################
# Test with COD_CLASIFICACION_DEUDOR_5_condicion_ult12meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [413]	training's auc: 0.868025	training's binary_logloss: 0.2836	valid_1's auc: 0.837884	valid_1's binary_logloss: 0.301956
# ####################
# Test with tipo_credito_13_condicion_ult12meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [426]	training's auc: 0.86864	training's binary_logloss: 0.283214	valid_1's auc: 0.838004	valid_1's binary_logloss: 0.301909
# ####################
# Test with COD_CLASIFICACION_DEUDOR_2_saldo_ult6meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [407]	training's auc: 0.868207	training's binary_logloss: 0.283507	valid_1's auc: 0.838497	valid_1's binary_logloss: 0.301544
# ####################
# Test with tipo_credito_11_condicion_ult2meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [403]	training's auc: 0.86743	training's binary_logloss: 0.283781	valid_1's auc: 0.837761	valid_1's binary_logloss: 0.301889
# ####################
# Test with RIESGO_DIRECTO_1_saldo_ult12meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [437]	training's auc: 0.869737	training's binary_logloss: 0.282399	valid_1's auc: 0.838677	valid_1's binary_logloss: 0.301296
# ####################
# Test with COD_CLASIFICACION_DEUDOR_5_saldo_ult6meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [415]	training's auc: 0.868032	training's binary_logloss: 0.283574	valid_1's auc: 0.838349	valid_1's binary_logloss: 0.30158
# ####################
# Test with COD_CLASIFICACION_DEUDOR_nunique_ult4mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [438]	training's auc: 0.868779	training's binary_logloss: 0.282912	valid_1's auc: 0.838024	valid_1's binary_logloss: 0.301808
# ####################
# Test with saldo_max_ult4mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [323]	training's auc: 0.86432	training's binary_logloss: 0.286606	valid_1's auc: 0.838345	valid_1's binary_logloss: 0.301938
# ####################
# Test with tipo_credito_12_condicion_ult6meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [365]	training's auc: 0.865953	training's binary_logloss: 0.284996	valid_1's auc: 0.837779	valid_1's binary_logloss: 0.30188
# ####################
# Test with saldo_std_ult4mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [340]	training's auc: 0.865189	training's binary_logloss: 0.285988	valid_1's auc: 0.837704	valid_1's binary_logloss: 0.302166
# ####################
# Test with PRODUCTO_max_ult2mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [548]	training's auc: 0.87314	training's binary_logloss: 0.279523	valid_1's auc: 0.838762	valid_1's binary_logloss: 0.30135
# ####################
# Test with RIESGO_DIRECTO_-1_saldo_ult12meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [493]	training's auc: 0.872652	training's binary_logloss: 0.280079	valid_1's auc: 0.83972	valid_1's binary_logloss: 0.300723
# ####################
# Test with tipo_credito_9_saldo_ult1meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [392]	training's auc: 0.867025	training's binary_logloss: 0.284587	valid_1's auc: 0.837827	valid_1's binary_logloss: 0.302023
# ####################
# Test with estadocontribuyente_nunique
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [427]	training's auc: 0.868367	training's binary_logloss: 0.283433	valid_1's auc: 0.838372	valid_1's binary_logloss: 0.301652
# ####################
# Test with RIESGO_DIRECTO_2_condicion_ult4meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [312]	training's auc: 0.862828	training's binary_logloss: 0.287534	valid_1's auc: 0.837008	valid_1's binary_logloss: 0.3024
# ####################
# Test with saldo_sum_ult6mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [295]	training's auc: 0.862602	training's binary_logloss: 0.287974	valid_1's auc: 0.83755	valid_1's binary_logloss: 0.302239
# ####################
# Test with saldo_mean_ult2mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [361]	training's auc: 0.86607	training's binary_logloss: 0.285309	valid_1's auc: 0.837988	valid_1's binary_logloss: 0.301989
# ####################
# Test with tipo_credito_11_saldo_ult4meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [401]	training's auc: 0.867509	training's binary_logloss: 0.284032	valid_1's auc: 0.837662	valid_1's binary_logloss: 0.302051
# ####################
# Test with tipo_credito_11_condicion_ult3meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [416]	training's auc: 0.86829	training's binary_logloss: 0.283281	valid_1's auc: 0.83789	valid_1's binary_logloss: 0.301678
# ####################
# Test with RIESGO_DIRECTO_1_condicion_ult5meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [405]	training's auc: 0.867675	training's binary_logloss: 0.283811	valid_1's auc: 0.838451	valid_1's binary_logloss: 0.301583
# ####################
# Test with tipo_credito_9_condicion_ult6meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [494]	training's auc: 0.871183	training's binary_logloss: 0.281076	valid_1's auc: 0.838653	valid_1's binary_logloss: 0.301489
# ####################
# Test with PRODUCTO_mode_ult2mes_me
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [423]	training's auc: 0.868807	training's binary_logloss: 0.283043	valid_1's auc: 0.838195	valid_1's binary_logloss: 0.301843
# ####################
# Test with PRODUCTO_mode_ult6mes_me
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [499]	training's auc: 0.871084	training's binary_logloss: 0.281154	valid_1's auc: 0.838293	valid_1's binary_logloss: 0.301549
# ####################
# Test with ctd_hijos
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [419]	training's auc: 0.868251	training's binary_logloss: 0.28345	valid_1's auc: 0.837893	valid_1's binary_logloss: 0.301949
# ####################
# Test with tipo_credito_10_condicion_ult12meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [555]	training's auc: 0.87361	training's binary_logloss: 0.279086	valid_1's auc: 0.838424	valid_1's binary_logloss: 0.301549
# ####################
# Test with COD_CLASIFICACION_DEUDOR_4_condicion_ult12meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [477]	training's auc: 0.870455	training's binary_logloss: 0.281764	valid_1's auc: 0.838379	valid_1's binary_logloss: 0.301548
# ####################
# Test with tipo_credito_9_condicion_ult5meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [428]	training's auc: 0.868275	training's binary_logloss: 0.283376	valid_1's auc: 0.838126	valid_1's binary_logloss: 0.301751
# ####################
# Test with COD_CLASIFICACION_DEUDOR_1_condicion_ult4meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [461]	training's auc: 0.869844	training's binary_logloss: 0.282095	valid_1's auc: 0.838357	valid_1's binary_logloss: 0.301371
# ####################
# Test with RIESGO_DIRECTO_-1_saldo_ult6meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [454]	training's auc: 0.870126	training's binary_logloss: 0.282008	valid_1's auc: 0.838661	valid_1's binary_logloss: 0.301369
# ####################
# Test with COD_CLASIFICACION_DEUDOR_std_ult6mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [398]	training's auc: 0.867105	training's binary_logloss: 0.284323	valid_1's auc: 0.838468	valid_1's binary_logloss: 0.301609
# ####################
# Test with COD_CLASIFICACION_DEUDOR_0_saldo_ult12meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [413]	training's auc: 0.869485	training's binary_logloss: 0.282604	valid_1's auc: 0.839243	valid_1's binary_logloss: 0.301063
# ####################
# Test with tipo_credito_10_saldo_ult5meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [391]	training's auc: 0.867358	training's binary_logloss: 0.284187	valid_1's auc: 0.838364	valid_1's binary_logloss: 0.301801
# ####################
# Test with COD_CLASIFICACION_DEUDOR_sum_ult2mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [382]	training's auc: 0.866679	training's binary_logloss: 0.284698	valid_1's auc: 0.83773	valid_1's binary_logloss: 0.301965
# ####################
# Test with PRODUCTO_max_ult6mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [393]	training's auc: 0.866699	training's binary_logloss: 0.284551	valid_1's auc: 0.838057	valid_1's binary_logloss: 0.301833
# ####################
# Test with COD_CLASIFICACION_DEUDOR_3_saldo_ult1meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [430]	training's auc: 0.868532	training's binary_logloss: 0.283189	valid_1's auc: 0.838003	valid_1's binary_logloss: 0.301847
# ####################
# Test with RIESGO_DIRECTO_2_condicion_ult2meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [348]	training's auc: 0.864745	training's binary_logloss: 0.286162	valid_1's auc: 0.837832	valid_1's binary_logloss: 0.302023
# ####################
# Test with COD_CLASIFICACION_DEUDOR_0_saldo_ult4meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [375]	training's auc: 0.866525	training's binary_logloss: 0.284808	valid_1's auc: 0.837651	valid_1's binary_logloss: 0.302115
# ####################
# Test with COD_CLASIFICACION_DEUDOR_sum_ult3mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [386]	training's auc: 0.866565	training's binary_logloss: 0.284777	valid_1's auc: 0.838002	valid_1's binary_logloss: 0.301795
# ####################
# Test with COD_CLASIFICACION_DEUDOR_3_saldo_ult2meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [344]	training's auc: 0.864878	training's binary_logloss: 0.286177	valid_1's auc: 0.837224	valid_1's binary_logloss: 0.30241
# ####################
# Test with ubigeo_mode
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [398]	training's auc: 0.868002	training's binary_logloss: 0.283745	valid_1's auc: 0.83826	valid_1's binary_logloss: 0.301689
# ####################
# Test with RIESGO_DIRECTO_1_saldo_ult2meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [413]	training's auc: 0.868233	training's binary_logloss: 0.283506	valid_1's auc: 0.83832	valid_1's binary_logloss: 0.30168
# ####################
# Test with COD_CLASIFICACION_DEUDOR_2_saldo_ult3meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [351]	training's auc: 0.865185	training's binary_logloss: 0.285882	valid_1's auc: 0.837395	valid_1's binary_logloss: 0.302285
# ####################
# Test with RIESGO_DIRECTO_2_condicion_ult12meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [379]	training's auc: 0.866349	training's binary_logloss: 0.284929	valid_1's auc: 0.837762	valid_1's binary_logloss: 0.301975
# ####################
# Test with COD_CLASIFICACION_DEUDOR_mean_ult5mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [374]	training's auc: 0.865878	training's binary_logloss: 0.285218	valid_1's auc: 0.838078	valid_1's binary_logloss: 0.301893
# ####################
# Test with condicion_mean_ult12mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [387]	training's auc: 0.867186	training's binary_logloss: 0.284408	valid_1's auc: 0.838021	valid_1's binary_logloss: 0.301874
# ####################
# Test with COD_CLASIFICACION_DEUDOR_sum_ult6mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [386]	training's auc: 0.866958	training's binary_logloss: 0.284483	valid_1's auc: 0.837861	valid_1's binary_logloss: 0.301969
# ####################
# Test with RIESGO_DIRECTO_-1_condicion_ult1meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [450]	training's auc: 0.869188	training's binary_logloss: 0.282659	valid_1's auc: 0.838541	valid_1's binary_logloss: 0.301384
# ####################
# Test with COD_CLASIFICACION_DEUDOR_5_condicion_ult4meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [356]	training's auc: 0.865167	training's binary_logloss: 0.285818	valid_1's auc: 0.837404	valid_1's binary_logloss: 0.3021
# ####################
# Test with saldo_sum_ult5mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [340]	training's auc: 0.864911	training's binary_logloss: 0.286143	valid_1's auc: 0.83759	valid_1's binary_logloss: 0.302151
# ####################
# Test with tipcontribuyente_mode
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [406]	training's auc: 0.867681	training's binary_logloss: 0.28386	valid_1's auc: 0.837866	valid_1's binary_logloss: 0.301928
# ####################
# Test with tipo_credito_10_saldo_ult12meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [447]	training's auc: 0.870036	training's binary_logloss: 0.282095	valid_1's auc: 0.839085	valid_1's binary_logloss: 0.301065
# ####################
# Test with RIESGO_DIRECTO_-1_condicion_ult2meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [316]	training's auc: 0.863594	training's binary_logloss: 0.287119	valid_1's auc: 0.837347	valid_1's binary_logloss: 0.30241
# ####################
# Test with condicion_sum_ult12mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [371]	training's auc: 0.866565	training's binary_logloss: 0.284879	valid_1's auc: 0.837943	valid_1's binary_logloss: 0.302098
# ####################
# Test with tipo_credito_12_condicion_ult4meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [428]	training's auc: 0.868894	training's binary_logloss: 0.282666	valid_1's auc: 0.838626	valid_1's binary_logloss: 0.301269
# ####################
# Test with COD_CLASIFICACION_DEUDOR_4_condicion_ult1meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [448]	training's auc: 0.869386	training's binary_logloss: 0.282551	valid_1's auc: 0.838057	valid_1's binary_logloss: 0.301793
# ####################
# Test with COD_CLASIFICACION_DEUDOR_2_saldo_ult4meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [308]	training's auc: 0.862696	training's binary_logloss: 0.287734	valid_1's auc: 0.837125	valid_1's binary_logloss: 0.302453
# ####################
# Test with cod_instit_financiera_min_ult3mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [480]	training's auc: 0.870862	training's binary_logloss: 0.281177	valid_1's auc: 0.838735	valid_1's binary_logloss: 0.301264
# ####################
# Test with tipo_credito_9_condicion_ult4meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [417]	training's auc: 0.868033	training's binary_logloss: 0.283435	valid_1's auc: 0.837773	valid_1's binary_logloss: 0.301868
# ####################
# Test with tipo_credito_12_condicion_ult2meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [345]	training's auc: 0.864843	training's binary_logloss: 0.285898	valid_1's auc: 0.837613	valid_1's binary_logloss: 0.302198
# ####################
# Test with COD_CLASIFICACION_DEUDOR_mode_ult6mes_me
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [344]	training's auc: 0.864545	training's binary_logloss: 0.286271	valid_1's auc: 0.837058	valid_1's binary_logloss: 0.302397
# ####################
# Test with RIESGO_DIRECTO_3_saldo_ult12meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [436]	training's auc: 0.868744	training's binary_logloss: 0.283013	valid_1's auc: 0.838117	valid_1's binary_logloss: 0.301701
# ####################
# Test with cod_instit_financiera_min_ult4mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [345]	training's auc: 0.86506	training's binary_logloss: 0.285967	valid_1's auc: 0.837606	valid_1's binary_logloss: 0.302201
# ####################
# Test with COD_CLASIFICACION_DEUDOR_2_condicion_ult6meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [422]	training's auc: 0.868623	training's binary_logloss: 0.283154	valid_1's auc: 0.838306	valid_1's binary_logloss: 0.301542
# ####################
# Test with COD_CLASIFICACION_DEUDOR_std_ult4mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [416]	training's auc: 0.867563	training's binary_logloss: 0.283828	valid_1's auc: 0.837756	valid_1's binary_logloss: 0.301983
# ####################
# Test with COD_CLASIFICACION_DEUDOR_2_condicion_ult3meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [279]	training's auc: 0.861206	training's binary_logloss: 0.288963	valid_1's auc: 0.837024	valid_1's binary_logloss: 0.302686
# ####################
# Test with condicion_sum_ult5mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [399]	training's auc: 0.867359	training's binary_logloss: 0.28404	valid_1's auc: 0.838548	valid_1's binary_logloss: 0.301554
# ####################
# Test with COD_CLASIFICACION_DEUDOR_3_saldo_ult3meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [429]	training's auc: 0.868421	training's binary_logloss: 0.283324	valid_1's auc: 0.838029	valid_1's binary_logloss: 0.301742
# ####################
# Test with cod_instit_financiera_max_ult5mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [453]	training's auc: 0.869416	training's binary_logloss: 0.2825	valid_1's auc: 0.838696	valid_1's binary_logloss: 0.301476
# ####################
# Test with COD_CLASIFICACION_DEUDOR_mean_ult6mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [339]	training's auc: 0.86446	training's binary_logloss: 0.286383	valid_1's auc: 0.83774	valid_1's binary_logloss: 0.302166
# ####################
# Test with RIESGO_DIRECTO_-1_saldo_ult4meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [448]	training's auc: 0.86962	training's binary_logloss: 0.282483	valid_1's auc: 0.838459	valid_1's binary_logloss: 0.301501
# ####################
# Test with PRODUCTO_mode_ult4mes_me
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [433]	training's auc: 0.868555	training's binary_logloss: 0.283155	valid_1's auc: 0.838254	valid_1's binary_logloss: 0.30172
# ####################
# Test with RIESGO_DIRECTO_-1_condicion_ult3meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [464]	training's auc: 0.870333	training's binary_logloss: 0.281735	valid_1's auc: 0.838475	valid_1's binary_logloss: 0.301362
# ####################
# Test with saldo_std_ult3mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [432]	training's auc: 0.869616	training's binary_logloss: 0.282476	valid_1's auc: 0.838742	valid_1's binary_logloss: 0.301495
# ####################
# Test with condicion_max_ult3mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [322]	training's auc: 0.863629	training's binary_logloss: 0.287058	valid_1's auc: 0.837268	valid_1's binary_logloss: 0.302365
# ####################
# Test with RIESGO_DIRECTO_1_condicion_ult6meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [423]	training's auc: 0.868768	training's binary_logloss: 0.283061	valid_1's auc: 0.838487	valid_1's binary_logloss: 0.301475
# ####################
# Test with cargorele_mode
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [482]	training's auc: 0.870922	training's binary_logloss: 0.281446	valid_1's auc: 0.838266	valid_1's binary_logloss: 0.301705
# ####################
# Test with COD_CLASIFICACION_DEUDOR_5_saldo_ult12meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [416]	training's auc: 0.867998	training's binary_logloss: 0.283493	valid_1's auc: 0.838147	valid_1's binary_logloss: 0.301748
# ####################
# Test with condicion_mean_ult5mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [382]	training's auc: 0.866577	training's binary_logloss: 0.28466	valid_1's auc: 0.838015	valid_1's binary_logloss: 0.301859
# ####################
# Test with tipo_credito_12_condicion_ult12meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [373]	training's auc: 0.866129	training's binary_logloss: 0.284965	valid_1's auc: 0.837756	valid_1's binary_logloss: 0.301982
# ####################
# Test with RIESGO_DIRECTO_-1_condicion_ult6meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [431]	training's auc: 0.86916	training's binary_logloss: 0.282682	valid_1's auc: 0.838405	valid_1's binary_logloss: 0.301504
# ####################
# Test with RIESGO_DIRECTO_1_saldo_ult5meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [384]	training's auc: 0.866978	training's binary_logloss: 0.284549	valid_1's auc: 0.83781	valid_1's binary_logloss: 0.302024
# ####################
# Test with saldo_max_ult2mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [329]	training's auc: 0.864743	training's binary_logloss: 0.286264	valid_1's auc: 0.837979	valid_1's binary_logloss: 0.301961
# ####################
# Test with RIESGO_DIRECTO_2_saldo_ult3meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [371]	training's auc: 0.86595	training's binary_logloss: 0.285289	valid_1's auc: 0.837707	valid_1's binary_logloss: 0.301978
# ####################
# Test with codvia_mode
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [419]	training's auc: 0.868268	training's binary_logloss: 0.283348	valid_1's auc: 0.837863	valid_1's binary_logloss: 0.301863
# ####################
# Test with tipo_credito_9_saldo_ult5meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [356]	training's auc: 0.865542	training's binary_logloss: 0.285607	valid_1's auc: 0.837778	valid_1's binary_logloss: 0.302156
# ####################
# Test with tipo_credito_10_condicion_ult3meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [409]	training's auc: 0.867634	training's binary_logloss: 0.283762	valid_1's auc: 0.838116	valid_1's binary_logloss: 0.30162
# ####################
# Test with tipo_credito_10_condicion_ult6meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [401]	training's auc: 0.867477	training's binary_logloss: 0.283919	valid_1's auc: 0.837949	valid_1's binary_logloss: 0.30191
# ####################
# Test with saldo_std_ult5mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [444]	training's auc: 0.87025	training's binary_logloss: 0.281894	valid_1's auc: 0.838656	valid_1's binary_logloss: 0.301206
# ####################
# Test with COD_CLASIFICACION_DEUDOR_0_condicion_ult12meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [327]	training's auc: 0.863817	training's binary_logloss: 0.286778	valid_1's auc: 0.837554	valid_1's binary_logloss: 0.3023
# ####################
# Test with saldo_min_ult1mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [424]	training's auc: 0.869753	training's binary_logloss: 0.282447	valid_1's auc: 0.838896	valid_1's binary_logloss: 0.301372
# ####################
# Test with tipo_credito_9_condicion_ult12meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [474]	training's auc: 0.870258	training's binary_logloss: 0.28181	valid_1's auc: 0.838238	valid_1's binary_logloss: 0.301617
# ####################
# Test with comercioexterior_mode
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [378]	training's auc: 0.866302	training's binary_logloss: 0.284925	valid_1's auc: 0.837691	valid_1's binary_logloss: 0.302066
# ####################
# Test with tipo_credito_10_condicion_ult4meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [471]	training's auc: 0.870024	training's binary_logloss: 0.281922	valid_1's auc: 0.838714	valid_1's binary_logloss: 0.301258
# ####################
# Test with COD_CLASIFICACION_DEUDOR_0_condicion_ult2meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [345]	training's auc: 0.864919	training's binary_logloss: 0.286035	valid_1's auc: 0.837437	valid_1's binary_logloss: 0.302149
# ####################
# Test with RIESGO_DIRECTO_-1_condicion_ult12meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [404]	training's auc: 0.86787	training's binary_logloss: 0.283751	valid_1's auc: 0.838136	valid_1's binary_logloss: 0.30169
# ####################
# Test with tipo_credito_99_condicion_ult1meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [355]	training's auc: 0.865185	training's binary_logloss: 0.285916	valid_1's auc: 0.837299	valid_1's binary_logloss: 0.302305
# ####################
# Test with cod_instit_financiera_mode_ult6mes_me
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [484]	training's auc: 0.870912	training's binary_logloss: 0.281394	valid_1's auc: 0.838791	valid_1's binary_logloss: 0.301406
# ####################
# Test with saldo_min_ult12mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [399]	training's auc: 0.868163	training's binary_logloss: 0.283646	valid_1's auc: 0.838472	valid_1's binary_logloss: 0.301626
# ####################
# Test with COD_CLASIFICACION_DEUDOR_3_saldo_ult5meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [491]	training's auc: 0.870826	training's binary_logloss: 0.281391	valid_1's auc: 0.838264	valid_1's binary_logloss: 0.301631
# ####################
# Test with tipo_credito_10_condicion_ult1meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [358]	training's auc: 0.865111	training's binary_logloss: 0.285852	valid_1's auc: 0.837667	valid_1's binary_logloss: 0.302115
# ####################
# Test with COD_CLASIFICACION_DEUDOR_1_condicion_ult2meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [291]	training's auc: 0.861708	training's binary_logloss: 0.288662	valid_1's auc: 0.837047	valid_1's binary_logloss: 0.302482
# ####################
# Test with COD_CLASIFICACION_DEUDOR_1_saldo_ult2meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [456]	training's auc: 0.869184	training's binary_logloss: 0.282589	valid_1's auc: 0.838643	valid_1's binary_logloss: 0.301524
# ####################
# Test with tipo_credito_12_saldo_ult1meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [347]	training's auc: 0.865298	training's binary_logloss: 0.28584	valid_1's auc: 0.838138	valid_1's binary_logloss: 0.301979
# ####################
# Test with cod_instit_financiera_nunique_ult5mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [392]	training's auc: 0.867418	training's binary_logloss: 0.284183	valid_1's auc: 0.838423	valid_1's binary_logloss: 0.301645
# ####################
# Test with PRODUCTO_max_ult1mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [465]	training's auc: 0.87089	training's binary_logloss: 0.281427	valid_1's auc: 0.838247	valid_1's binary_logloss: 0.301446
# ####################
# Test with cod_instit_financiera_min_ult2mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [284]	training's auc: 0.861858	training's binary_logloss: 0.288503	valid_1's auc: 0.837055	valid_1's binary_logloss: 0.302714
# ####################
# Test with tipo_credito_11_condicion_ult12meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [427]	training's auc: 0.869349	training's binary_logloss: 0.282517	valid_1's auc: 0.838968	valid_1's binary_logloss: 0.301185
# ####################
# Test with lgr_vot_me
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [462]	training's auc: 0.870073	training's binary_logloss: 0.282019	valid_1's auc: 0.838225	valid_1's binary_logloss: 0.301704
# ####################
# Test with tipo_credito_11_condicion_ult6meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [414]	training's auc: 0.868028	training's binary_logloss: 0.2834	valid_1's auc: 0.838352	valid_1's binary_logloss: 0.301419
# ####################
# Test with COD_CLASIFICACION_DEUDOR_4_saldo_ult4meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [327]	training's auc: 0.86404	training's binary_logloss: 0.28673	valid_1's auc: 0.837398	valid_1's binary_logloss: 0.302433
# ####################
# Test with cargorele_nunique
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [418]	training's auc: 0.868045	training's binary_logloss: 0.283535	valid_1's auc: 0.838225	valid_1's binary_logloss: 0.30174
# ####################
# Test with PRODUCTO_nunique_ult2mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [352]	training's auc: 0.865283	training's binary_logloss: 0.285768	valid_1's auc: 0.837585	valid_1's binary_logloss: 0.302224
# ####################
# Test with saldo_max_ult1mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [520]	training's auc: 0.872798	training's binary_logloss: 0.279783	valid_1's auc: 0.839176	valid_1's binary_logloss: 0.301148
# ####################
# Test with COD_CLASIFICACION_DEUDOR_4_saldo_ult3meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [424]	training's auc: 0.868162	training's binary_logloss: 0.283471	valid_1's auc: 0.837879	valid_1's binary_logloss: 0.301913
# ####################
# Test with tipo_credito_11_condicion_ult5meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [421]	training's auc: 0.868324	training's binary_logloss: 0.283166	valid_1's auc: 0.837977	valid_1's binary_logloss: 0.301672
# ####################
# Test with saldo_sum_ult4mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [338]	training's auc: 0.864534	training's binary_logloss: 0.286409	valid_1's auc: 0.837938	valid_1's binary_logloss: 0.301976
# ####################
# Test with codentidadtributo_mode
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [499]	training's auc: 0.871227	training's binary_logloss: 0.281082	valid_1's auc: 0.838226	valid_1's binary_logloss: 0.301676
# ####################
# Test with COD_CLASIFICACION_DEUDOR_2_saldo_ult1meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [393]	training's auc: 0.866484	training's binary_logloss: 0.284839	valid_1's auc: 0.83756	valid_1's binary_logloss: 0.302155
# ####################
# Test with tipo_credito_11_condicion_ult4meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [254]	training's auc: 0.860035	training's binary_logloss: 0.289827	valid_1's auc: 0.83673	valid_1's binary_logloss: 0.302673
# ####################
# Test with COD_CLASIFICACION_DEUDOR_3_saldo_ult4meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [405]	training's auc: 0.867298	training's binary_logloss: 0.284145	valid_1's auc: 0.837965	valid_1's binary_logloss: 0.301821
# ####################
# Test with RIESGO_DIRECTO_1_saldo_ult6meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [353]	training's auc: 0.86564	training's binary_logloss: 0.285433	valid_1's auc: 0.837936	valid_1's binary_logloss: 0.301929
# ####################
# Test with tipo_credito_13_saldo_ult6meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [417]	training's auc: 0.868369	training's binary_logloss: 0.2834	valid_1's auc: 0.837999	valid_1's binary_logloss: 0.301773
# ####################
# Test with PRODUCTO_min_ult3mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [410]	training's auc: 0.867538	training's binary_logloss: 0.284012	valid_1's auc: 0.838308	valid_1's binary_logloss: 0.301687
# ####################
# Test with COD_CLASIFICACION_DEUDOR_5_saldo_ult2meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [376]	training's auc: 0.866418	training's binary_logloss: 0.284874	valid_1's auc: 0.838005	valid_1's binary_logloss: 0.301899
# ####################
# Test with saldo_max_ult6mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [440]	training's auc: 0.869899	training's binary_logloss: 0.282217	valid_1's auc: 0.838756	valid_1's binary_logloss: 0.301427
# ####################
# Test with COD_CLASIFICACION_DEUDOR_2_condicion_ult4meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [445]	training's auc: 0.869234	training's binary_logloss: 0.282627	valid_1's auc: 0.837931	valid_1's binary_logloss: 0.301844
# ####################
# Test with COD_CLASIFICACION_DEUDOR_0_condicion_ult1meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [369]	training's auc: 0.865956	training's binary_logloss: 0.285215	valid_1's auc: 0.83841	valid_1's binary_logloss: 0.301683
# ####################
# Test with contabilidad_nunique
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [505]	training's auc: 0.871861	training's binary_logloss: 0.280569	valid_1's auc: 0.83846	valid_1's binary_logloss: 0.30153
# ####################
# Test with COD_CLASIFICACION_DEUDOR_4_saldo_ult6meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [404]	training's auc: 0.867826	training's binary_logloss: 0.283811	valid_1's auc: 0.838499	valid_1's binary_logloss: 0.301619
# ####################
# Test with RIESGO_DIRECTO_-1_saldo_ult2meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [397]	training's auc: 0.866947	training's binary_logloss: 0.284403	valid_1's auc: 0.838342	valid_1's binary_logloss: 0.301583
# ####################
# Test with COD_CLASIFICACION_DEUDOR_4_saldo_ult1meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [403]	training's auc: 0.867785	training's binary_logloss: 0.283964	valid_1's auc: 0.837891	valid_1's binary_logloss: 0.301988
# ####################
# Test with condicion_std_ult4mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [374]	training's auc: 0.866224	training's binary_logloss: 0.285051	valid_1's auc: 0.837948	valid_1's binary_logloss: 0.302003
# ####################
# Test with COD_CLASIFICACION_DEUDOR_sum_ult5mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [318]	training's auc: 0.86337	training's binary_logloss: 0.28725	valid_1's auc: 0.837318	valid_1's binary_logloss: 0.302528
# ####################
# Test with tipo_credito_12_saldo_ult5meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [373]	training's auc: 0.86648	training's binary_logloss: 0.28484	valid_1's auc: 0.837941	valid_1's binary_logloss: 0.301942
# ####################
# Test with condicion_mean_ult2mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [415]	training's auc: 0.867656	training's binary_logloss: 0.283803	valid_1's auc: 0.837941	valid_1's binary_logloss: 0.301991
# ####################
# Test with COD_CLASIFICACION_DEUDOR_5_saldo_ult4meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [409]	training's auc: 0.86756	training's binary_logloss: 0.283872	valid_1's auc: 0.83765	valid_1's binary_logloss: 0.302009
# ####################
# Test with RIESGO_DIRECTO_2_saldo_ult2meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [450]	training's auc: 0.868542	training's binary_logloss: 0.283028	valid_1's auc: 0.8378	valid_1's binary_logloss: 0.301767
# ####################
# Test with tipo_credito_13_saldo_ult5meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [415]	training's auc: 0.868071	training's binary_logloss: 0.283563	valid_1's auc: 0.837978	valid_1's binary_logloss: 0.301801
# ####################
# Test with saldo_min_ult4mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [452]	training's auc: 0.870014	training's binary_logloss: 0.282098	valid_1's auc: 0.838688	valid_1's binary_logloss: 0.301483
# ####################
# Test with COD_CLASIFICACION_DEUDOR_3_condicion_ult6meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [407]	training's auc: 0.867774	training's binary_logloss: 0.283907	valid_1's auc: 0.838083	valid_1's binary_logloss: 0.301932
# ####################
# Test with cod_instit_financiera_nunique_ult6mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [400]	training's auc: 0.866984	training's binary_logloss: 0.284367	valid_1's auc: 0.838494	valid_1's binary_logloss: 0.301635
# ####################
# Test with condicion_max_ult4mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [411]	training's auc: 0.868011	training's binary_logloss: 0.283654	valid_1's auc: 0.83809	valid_1's binary_logloss: 0.301828
# ####################
# Test with RIESGO_DIRECTO_2_condicion_ult5meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [382]	training's auc: 0.866742	training's binary_logloss: 0.284633	valid_1's auc: 0.837779	valid_1's binary_logloss: 0.301984
# ####################
# Test with COD_CLASIFICACION_DEUDOR_1_saldo_ult3meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [405]	training's auc: 0.867661	training's binary_logloss: 0.283935	valid_1's auc: 0.837837	valid_1's binary_logloss: 0.302099
# ####################
# Test with COD_CLASIFICACION_DEUDOR_1_saldo_ult5meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [370]	training's auc: 0.866165	training's binary_logloss: 0.284971	valid_1's auc: 0.837905	valid_1's binary_logloss: 0.301974
# ####################
# Test with RIESGO_DIRECTO_-1_condicion_ult4meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [469]	training's auc: 0.870168	training's binary_logloss: 0.281779	valid_1's auc: 0.838203	valid_1's binary_logloss: 0.301557
# ####################
# Test with tipo_credito_13_saldo_ult2meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [459]	training's auc: 0.869808	training's binary_logloss: 0.282155	valid_1's auc: 0.838154	valid_1's binary_logloss: 0.301664
# ####################
# Test with COD_CLASIFICACION_DEUDOR_5_saldo_ult3meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [464]	training's auc: 0.869893	training's binary_logloss: 0.282049	valid_1's auc: 0.838275	valid_1's binary_logloss: 0.301495
# ####################
# Test with COD_CLASIFICACION_DEUDOR_2_condicion_ult12meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [314]	training's auc: 0.863741	training's binary_logloss: 0.286963	valid_1's auc: 0.837414	valid_1's binary_logloss: 0.302219
# ####################
# Test with condiciondomicilio_nunique
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [328]	training's auc: 0.864089	training's binary_logloss: 0.286774	valid_1's auc: 0.837065	valid_1's binary_logloss: 0.302546
# ####################
# Test with facturacion_nunique
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [431]	training's auc: 0.869119	training's binary_logloss: 0.282817	valid_1's auc: 0.838303	valid_1's binary_logloss: 0.301654
# ####################
# Test with saldo_sum_ult3mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [280]	training's auc: 0.860942	training's binary_logloss: 0.289016	valid_1's auc: 0.8368	valid_1's binary_logloss: 0.302717
# ####################
# Test with COD_CLASIFICACION_DEUDOR_0_condicion_ult5meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [368]	training's auc: 0.865683	training's binary_logloss: 0.2854	valid_1's auc: 0.837977	valid_1's binary_logloss: 0.301984
# ####################
# Test with comercioexterior_nunique
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [444]	training's auc: 0.869158	training's binary_logloss: 0.282776	valid_1's auc: 0.838053	valid_1's binary_logloss: 0.301798
# ####################
# Test with condicion_std_ult12mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [435]	training's auc: 0.869115	training's binary_logloss: 0.282747	valid_1's auc: 0.838566	valid_1's binary_logloss: 0.301561
# ####################
# Test with COD_CLASIFICACION_DEUDOR_5_saldo_ult1meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [480]	training's auc: 0.870518	training's binary_logloss: 0.281573	valid_1's auc: 0.838516	valid_1's binary_logloss: 0.301466
# ####################
# Test with RIESGO_DIRECTO_2_condicion_ult3meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [371]	training's auc: 0.866004	training's binary_logloss: 0.285207	valid_1's auc: 0.837993	valid_1's binary_logloss: 0.301984
# ####################
# Test with tipo_credito_12_condicion_ult1meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [315]	training's auc: 0.863504	training's binary_logloss: 0.286984	valid_1's auc: 0.837243	valid_1's binary_logloss: 0.302335
# ####################
# Test with tipo_credito_13_condicion_ult1meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [334]	training's auc: 0.864262	training's binary_logloss: 0.286701	valid_1's auc: 0.837563	valid_1's binary_logloss: 0.30236
# ####################
# Test with COD_CLASIFICACION_DEUDOR_4_condicion_ult6meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [416]	training's auc: 0.867348	training's binary_logloss: 0.284103	valid_1's auc: 0.83787	valid_1's binary_logloss: 0.301892
# ####################
# Test with tipo_credito_99_saldo_ult3meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [402]	training's auc: 0.867643	training's binary_logloss: 0.283946	valid_1's auc: 0.837759	valid_1's binary_logloss: 0.301958
# ####################
# Test with COD_CLASIFICACION_DEUDOR_max_ult12mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [448]	training's auc: 0.869031	training's binary_logloss: 0.282684	valid_1's auc: 0.838021	valid_1's binary_logloss: 0.301684
# ####################
# Test with PRODUCTO_mode_ult12mes_me
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [363]	training's auc: 0.866096	training's binary_logloss: 0.285295	valid_1's auc: 0.837848	valid_1's binary_logloss: 0.301961
# ####################
# Test with COD_CLASIFICACION_DEUDOR_max_ult6mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [408]	training's auc: 0.867423	training's binary_logloss: 0.284153	valid_1's auc: 0.83788	valid_1's binary_logloss: 0.301898
# ...
# [401]	training's auc: 0.867388	training's binary_logloss: 0.284119	valid_1's auc: 0.837874	valid_1's binary_logloss: 0.301832
# ####################
# Test with COD_CLASIFICACION_DEUDOR_std_ult3mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [437]	training's auc: 0.869164	training's binary_logloss: 0.282675	valid_1's auc: 0.838481	valid_1's binary_logloss: 0.301493
# ####################
# Test with saldo_mean_ult5mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [339]	training's auc: 0.864908	training's binary_logloss: 0.286338	valid_1's auc: 0.837492	valid_1's binary_logloss: 0.302265
# ####################
# Test with codzona_mode
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [482]	training's auc: 0.870716	training's binary_logloss: 0.281512	valid_1's auc: 0.838292	valid_1's binary_logloss: 0.301491
# ####################
# Test with COD_CLASIFICACION_DEUDOR_0_condicion_ult6meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [427]	training's auc: 0.867766	training's binary_logloss: 0.283636	valid_1's auc: 0.837758	valid_1's binary_logloss: 0.301963
# ####################
# Test with tipo_credito_12_saldo_ult2meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [345]	training's auc: 0.864482	training's binary_logloss: 0.286375	valid_1's auc: 0.837526	valid_1's binary_logloss: 0.302198
# ####################
# Test with tipo_credito_9_saldo_ult3meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [542]	training's auc: 0.872935	training's binary_logloss: 0.279785	valid_1's auc: 0.838357	valid_1's binary_logloss: 0.301619
# ####################
# Test with COD_CLASIFICACION_DEUDOR_5_condicion_ult6meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [359]	training's auc: 0.865163	training's binary_logloss: 0.285726	valid_1's auc: 0.837353	valid_1's binary_logloss: 0.302246
# ####################
# Test with condicion_mean_ult4mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [351]	training's auc: 0.865455	training's binary_logloss: 0.285651	valid_1's auc: 0.837807	valid_1's binary_logloss: 0.301976
# ####################
# Test with PRODUCTO_nunique_ult5mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [507]	training's auc: 0.871376	training's binary_logloss: 0.280955	valid_1's auc: 0.838728	valid_1's binary_logloss: 0.301416
# ####################
# Test with condicion_std_ult3mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [331]	training's auc: 0.864157	training's binary_logloss: 0.2867	valid_1's auc: 0.837236	valid_1's binary_logloss: 0.302496
# ####################
# Test with cod_instit_financiera_mode_ult5mes_me
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [367]	training's auc: 0.866125	training's binary_logloss: 0.285216	valid_1's auc: 0.83814	valid_1's binary_logloss: 0.301835
# ####################
# Test with RIESGO_DIRECTO_2_saldo_ult5meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [429]	training's auc: 0.868308	training's binary_logloss: 0.283361	valid_1's auc: 0.838183	valid_1's binary_logloss: 0.301777
# ####################
# Test with COD_CLASIFICACION_DEUDOR_1_condicion_ult3meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [434]	training's auc: 0.868832	training's binary_logloss: 0.282879	valid_1's auc: 0.838188	valid_1's binary_logloss: 0.301749
# ####################
# Test with saldo_sum_ult12mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [387]	training's auc: 0.868174	training's binary_logloss: 0.283706	valid_1's auc: 0.838912	valid_1's binary_logloss: 0.301334
# ####################
# Test with COD_CLASIFICACION_DEUDOR_2_saldo_ult2meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [347]	training's auc: 0.865389	training's binary_logloss: 0.285761	valid_1's auc: 0.83768	valid_1's binary_logloss: 0.302157
# ####################
# Test with condiciondomicilio_mode
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [357]	training's auc: 0.865419	training's binary_logloss: 0.2857	valid_1's auc: 0.837772	valid_1's binary_logloss: 0.302117
# ####################
# Test with saldo_std_ult12mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [305]	training's auc: 0.863337	training's binary_logloss: 0.287302	valid_1's auc: 0.83805	valid_1's binary_logloss: 0.302067
# ####################
# Test with RIESGO_DIRECTO_-1_saldo_ult1meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [290]	training's auc: 0.86204	training's binary_logloss: 0.28829	valid_1's auc: 0.837326	valid_1's binary_logloss: 0.302345
# ####################
# Test with COD_CLASIFICACION_DEUDOR_3_condicion_ult2meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [440]	training's auc: 0.868928	training's binary_logloss: 0.282867	valid_1's auc: 0.838272	valid_1's binary_logloss: 0.301663
# ####################
# Test with tipo_credito_13_saldo_ult12meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [470]	training's auc: 0.870407	training's binary_logloss: 0.281824	valid_1's auc: 0.838317	valid_1's binary_logloss: 0.301614
# ####################
# Test with COD_CLASIFICACION_DEUDOR_sum_ult4mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [307]	training's auc: 0.863278	training's binary_logloss: 0.287287	valid_1's auc: 0.837803	valid_1's binary_logloss: 0.302336
# ####################
# Test with tipo_credito_10_saldo_ult3meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [327]	training's auc: 0.86347	training's binary_logloss: 0.287177	valid_1's auc: 0.837482	valid_1's binary_logloss: 0.302268
# ####################
# Test with facturacion_mode
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [488]	training's auc: 0.870714	training's binary_logloss: 0.281529	valid_1's auc: 0.83797	valid_1's binary_logloss: 0.301871
# ####################
# Test with tipo_credito_13_condicion_ult3meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [345]	training's auc: 0.864525	training's binary_logloss: 0.286295	valid_1's auc: 0.837342	valid_1's binary_logloss: 0.302272
# ####################
# Test with COD_CLASIFICACION_DEUDOR_1_saldo_ult12meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [441]	training's auc: 0.868806	training's binary_logloss: 0.282941	valid_1's auc: 0.838307	valid_1's binary_logloss: 0.301654
# ####################
# Test with tipo_credito_11_saldo_ult6meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [443]	training's auc: 0.869198	training's binary_logloss: 0.28269	valid_1's auc: 0.83831	valid_1's binary_logloss: 0.301686
# ####################
# Test with saldo_max_ult3mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [454]	training's auc: 0.870306	training's binary_logloss: 0.281797	valid_1's auc: 0.83919	valid_1's binary_logloss: 0.301124
# ####################
# Test with codzona_nunique
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [294]	training's auc: 0.862253	training's binary_logloss: 0.288284	valid_1's auc: 0.836595	valid_1's binary_logloss: 0.30286
# ####################
# Test with tipo_credito_13_saldo_ult3meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [409]	training's auc: 0.867496	training's binary_logloss: 0.283954	valid_1's auc: 0.837547	valid_1's binary_logloss: 0.301988
# ####################
# Test with COD_CLASIFICACION_DEUDOR_mean_ult2mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [278]	training's auc: 0.861192	training's binary_logloss: 0.288857	valid_1's auc: 0.836769	valid_1's binary_logloss: 0.302863
# ####################
# Test with RIESGO_DIRECTO_2_saldo_ult4meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [376]	training's auc: 0.866398	training's binary_logloss: 0.284801	valid_1's auc: 0.837685	valid_1's binary_logloss: 0.302125
# ####################
# Test with COD_CLASIFICACION_DEUDOR_4_saldo_ult5meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [417]	training's auc: 0.867997	training's binary_logloss: 0.283656	valid_1's auc: 0.837839	valid_1's binary_logloss: 0.30202
# ####################
# Test with COD_CLASIFICACION_DEUDOR_nunique_ult5mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [437]	training's auc: 0.86884	training's binary_logloss: 0.28294	valid_1's auc: 0.838333	valid_1's binary_logloss: 0.301635
# ####################
# Test with condicion_mean_ult3mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [467]	training's auc: 0.8704	training's binary_logloss: 0.281709	valid_1's auc: 0.838111	valid_1's binary_logloss: 0.301818
# ####################
# Test with COD_CLASIFICACION_DEUDOR_4_saldo_ult12meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [362]	training's auc: 0.865596	training's binary_logloss: 0.285419	valid_1's auc: 0.837796	valid_1's binary_logloss: 0.301906
# ####################
# Test with COD_CLASIFICACION_DEUDOR_1_condicion_ult5meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [422]	training's auc: 0.868733	training's binary_logloss: 0.28306	valid_1's auc: 0.838459	valid_1's binary_logloss: 0.301378
# ####################
# Test with RIESGO_DIRECTO_2_condicion_ult6meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [382]	training's auc: 0.866093	training's binary_logloss: 0.285054	valid_1's auc: 0.838146	valid_1's binary_logloss: 0.30179
# ####################
# Test with RIESGO_DIRECTO_-1_saldo_ult5meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [409]	training's auc: 0.868483	training's binary_logloss: 0.283493	valid_1's auc: 0.838086	valid_1's binary_logloss: 0.301896
# ####################
# Test with RIESGO_DIRECTO_-1_saldo_ult3meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [431]	training's auc: 0.868826	training's binary_logloss: 0.282965	valid_1's auc: 0.8386	valid_1's binary_logloss: 0.301547
# ####################
# Test with cod_instit_financiera_mode_ult3mes_me
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [385]	training's auc: 0.866629	training's binary_logloss: 0.284723	valid_1's auc: 0.838134	valid_1's binary_logloss: 0.301792
# ####################
# Test with PRODUCTO_nunique_ult6mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [433]	training's auc: 0.869198	training's binary_logloss: 0.282702	valid_1's auc: 0.838052	valid_1's binary_logloss: 0.301818
# ####################
# Test with tipo_credito_10_saldo_ult4meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [443]	training's auc: 0.869174	training's binary_logloss: 0.282749	valid_1's auc: 0.838732	valid_1's binary_logloss: 0.301487
# ####################
# Test with COD_CLASIFICACION_DEUDOR_mean_ult12mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [425]	training's auc: 0.868057	training's binary_logloss: 0.28357	valid_1's auc: 0.838055	valid_1's binary_logloss: 0.30171
# ####################
# Test with tipo_credito_9_condicion_ult3meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [417]	training's auc: 0.867994	training's binary_logloss: 0.283589	valid_1's auc: 0.837822	valid_1's binary_logloss: 0.301887
# ####################
# Test with COD_CLASIFICACION_DEUDOR_2_condicion_ult1meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [358]	training's auc: 0.865342	training's binary_logloss: 0.285809	valid_1's auc: 0.837575	valid_1's binary_logloss: 0.302213
# ####################
# Test with saldo_std_ult6mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [318]	training's auc: 0.864187	training's binary_logloss: 0.286724	valid_1's auc: 0.837666	valid_1's binary_logloss: 0.302289
# ####################
# Test with cod_instit_financiera_max_ult2mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [354]	training's auc: 0.86561	training's binary_logloss: 0.285523	valid_1's auc: 0.838059	valid_1's binary_logloss: 0.301895
# ####################
# Test with COD_CLASIFICACION_DEUDOR_3_condicion_ult5meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [312]	training's auc: 0.862956	training's binary_logloss: 0.287601	valid_1's auc: 0.837093	valid_1's binary_logloss: 0.302606
# ####################
# Test with COD_CLASIFICACION_DEUDOR_std_ult5mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [359]	training's auc: 0.864864	training's binary_logloss: 0.286053	valid_1's auc: 0.837408	valid_1's binary_logloss: 0.302235
# ####################
# Test with PRODUCTO_max_ult3mes
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [391]	training's auc: 0.86734	training's binary_logloss: 0.284182	valid_1's auc: 0.837833	valid_1's binary_logloss: 0.301817
# ####################
# Test with tipo_credito_13_condicion_ult6meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [356]	training's auc: 0.865264	training's binary_logloss: 0.285812	valid_1's auc: 0.837585	valid_1's binary_logloss: 0.302137
# ####################
# Test with COD_CLASIFICACION_DEUDOR_4_saldo_ult2meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [374]	training's auc: 0.866009	training's binary_logloss: 0.285177	valid_1's auc: 0.837653	valid_1's binary_logloss: 0.302139
# ####################
# Test with tipo_credito_99_condicion_ult2meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [506]	training's auc: 0.871492	training's binary_logloss: 0.280869	valid_1's auc: 0.83837	valid_1's binary_logloss: 0.30154
# ####################
# Test with COD_CLASIFICACION_DEUDOR_1_saldo_ult4meses
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [405]	training's auc: 0.867403	training's binary_logloss: 0.284081	valid_1's auc: 0.838233	valid_1's binary_logloss: 0.301756
# ####################
# Test with tippersona_mode
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [385]	training's auc: 0.866809	training's binary_logloss: 0.284637	valid_1's auc: 0.837899	valid_1's binary_logloss: 0.301949
# ####################
# Test with COD_CLASIFICACION_DEUDOR_1_condicion_ult12meses
# Training until validation scores don't improve for 10 rounds

# %%
Test with RIESGO_DIRECTO_-1_saldo_ult12meses
Training until validation scores don't improve for 10 rounds
Early stopping, best iteration is:
[493]	training's auc: 0.872652	training's binary_logloss: 0.280079	valid_1's auc: 0.83972	valid_1's binary_logloss: 0.300723
####################
