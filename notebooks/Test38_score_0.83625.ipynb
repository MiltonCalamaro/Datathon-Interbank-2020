# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/interbank20/sample_submission.csv
# /kaggle/input/interbank20/y_train.csv
# /kaggle/input/interbank20/sunat_test.csv
# /kaggle/input/interbank20/rcc_test.csv
# /kaggle/input/interbank20/se_test.csv
# /kaggle/input/interbank20/sunat_train.csv
# /kaggle/input/interbank20/se_train.csv
# /kaggle/input/interbank20/censo_test.csv
# /kaggle/input/interbank20/productos.csv
# /kaggle/input/interbank20/censo_train.csv
# /kaggle/input/interbank20/rcc_train.csv

# %% [markdown]
# ## Load RCC

# %%
rcc_train = pd.read_csv('/kaggle/input/interbank20/rcc_train.csv')
rcc_test = pd.read_csv('/kaggle/input/interbank20/rcc_test.csv')
y_train = pd.read_csv('/kaggle/input/interbank20/y_train.csv', index_col='key_value')

# %%
# bins = [-1, 0, 10, 20, 30, 60, 90, 180, 360, 720, float("inf")]
# rcc_train["condicion"] = pd.cut(rcc_train.condicion, bins, labels = range(0,10)).astype('int32')
# rcc_test["condicion"] = pd.cut(rcc_test.condicion, bins, labels = range(0,10)).astype('int32')
rcc_test['cod_instit_financiera'].fillna(rcc_test['cod_instit_financiera'].value_counts().index[0], inplace=True)
rcc_test['PRODUCTO'].fillna(rcc_test['PRODUCTO'].value_counts().index[0], inplace=True)

# %%
dict_ = dict(zip(list(rcc_train.dtypes[rcc_train.dtypes == int].index), ['int32']*len(rcc_train.dtypes[rcc_train.dtypes == int].index)))
rcc_train = rcc_train.astype(dict_)
rcc_test = rcc_test.astype(dict_)

# %%
import statistics as stat
import numpy as np
def calculate_mode(x):
    try:
        moda=stat.mode(x)
    except:
        moda=np.nan
    return moda

# %%
from tqdm.notebook import tqdm 
import gc
list_rcc_train_agg = []

moda=lambda x: calculate_mode(x)
moda.__name__='mode'
agg_rcc = {'condicion':['max','min','mean','std'],
           'saldo':['max','min','mean','std'],
           'cod_instit_financiera':['nunique',moda],
           'PRODUCTO':['nunique',moda],
           'COD_CLASIFICACION_DEUDOR':['nunique','max','min','sum',moda]
          }

# %%
for n,i in enumerate(tqdm(sorted(set(rcc_train.codmes),reverse=True))):
#     if i in [201802,201712,201709,201703]:
    if n in [0,1,2,3,4,5,11]:
        for c in ['tipo_credito','RIESGO_DIRECTO','COD_CLASIFICACION_DEUDOR']:
            print(f'haciendo {c}')
            rcc_train_agg = rcc_train[rcc_train.codmes>=i].groupby(['key_value', c]).saldo.sum().unstack(level = 1, fill_value=0)
            rcc_train_agg.columns = [f'{rcc_train_agg.columns.name}_{c}_saldo_ult{n+1}meses' for c in rcc_train_agg.columns]
            list_rcc_train_agg.append(rcc_train_agg)
            gc.collect()
        for c in ['tipo_credito','RIESGO_DIRECTO','COD_CLASIFICACION_DEUDOR']:
            print(f'haciendo {c}')
            rcc_train_agg = rcc_train[rcc_train.codmes>=i].groupby(['key_value', c]).condicion.sum().unstack(level = 1, fill_value=0)
            rcc_train_agg.columns = [f'{rcc_train_agg.columns.name}_{c}_condicion_ult{n+1}meses' for c in rcc_train_agg.columns]
            list_rcc_train_agg.append(rcc_train_agg)
            gc.collect()

        print(f'haciendo agg ')
        rcc_train_agg = rcc_train[rcc_train.codmes>=i].groupby('key_value').agg(agg_rcc)
        rcc_train_agg.columns = [i+'_'+j+f'_ult{n+1}mes' for i,j in rcc_train_agg.columns]
        list_rcc_train_agg.append(rcc_train_agg)
        gc.collect()
        
rcc_train_ = pd.concat(list_rcc_train_agg, axis=1)
del rcc_train, list_rcc_train_agg
# Out:
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg

# %%
from tqdm.notebook import tqdm 
list_rcc_test_agg = []
for n,i in enumerate(tqdm(sorted(set(rcc_test.codmes),reverse=True))):
#     if i in [201902,201812,201809,201803]:
    if n in [0,1,2,3,4,5,11]:
        for c in ['tipo_credito','RIESGO_DIRECTO','COD_CLASIFICACION_DEUDOR']:
            print(f'haciendo {c}')
            rcc_test_agg = rcc_test[rcc_test.codmes>=i].groupby(['key_value', c]).saldo.sum().unstack(level = 1, fill_value=0)
            rcc_test_agg.columns = [f'{rcc_test_agg.columns.name}_{c}_saldo_ult{n+1}meses' for c in rcc_test_agg.columns]
            list_rcc_test_agg.append(rcc_test_agg)
            gc.collect()
        for c in ['tipo_credito','RIESGO_DIRECTO','COD_CLASIFICACION_DEUDOR']:
            print(f'haciendo {c}')
            rcc_test_agg = rcc_test[rcc_test.codmes>=i].groupby(['key_value', c]).condicion.sum().unstack(level = 1, fill_value=0)
            rcc_test_agg.columns = [f'{rcc_test_agg.columns.name}_{c}_condicion_ult{n+1}meses' for c in rcc_test_agg.columns]
            list_rcc_test_agg.append(rcc_test_agg)
            gc.collect()
        print(f'haciendo agg')    
        rcc_test_agg = rcc_test[rcc_test.codmes>=i].groupby('key_value').agg(agg_rcc)
        rcc_test_agg.columns = [i+'_'+j+f'_ult{n+1}mes' for i,j in rcc_test_agg.columns]
        list_rcc_test_agg.append(rcc_test_agg)
        gc.collect()

rcc_test_ = pd.concat(list_rcc_test_agg, axis=1)
del rcc_test, list_rcc_test_agg
# Out:
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo tipo_credito
# haciendo RIESGO_DIRECTO
# haciendo COD_CLASIFICACION_DEUDOR
# haciendo agg

# %%
print(rcc_train_.shape, rcc_test_.shape)
keep_columns = list(set(rcc_train_.columns).intersection(rcc_test_.columns))
rcc_train_ = rcc_train_[keep_columns].copy()
rcc_test_ = rcc_test_[keep_columns].copy()
print(rcc_train_.shape, rcc_test_.shape)
# Out:
# (358487, 385) (396666, 399)
# (358487, 385) (396666, 385)

# %%
train = rcc_train_.copy()
test = rcc_test_.copy()
del rcc_train_, rcc_test_

# %%
for i in [1,2,3,4,5,6,12]:
    train[f'ratio_condicion_saldo_ult{i}mes'] = train[f'condicion_max_ult{i}mes']/train[f'saldo_max_ult{i}mes']
    test[f'ratio_condicion_saldo_ult{i}mes'] = test[f'condicion_max_ult{i}mes']/test[f'saldo_max_ult{i}mes']

# %%
### imputar datos categoricos
var_categ = [i for i in train.columns if 'mode' in i]
for i in var_categ:
    train[i] = train[i].fillna(train[i].value_counts().index[0])
    test[i] = test[i].fillna(train[i].value_counts().index[0])

# %%
### mean encoding
### ojo, en el test hay missing values pero pocos
train = pd.concat([train, y_train], axis=1)
for i in var_categ:
    me = train.groupby([i])['target'].mean().to_dict() 
    train[f'{i}_me'] =  train[i].map(me) 
    test[f'{i}_me'] =  test[i].map(me)
    ### imputar datos faltantes
    test[f'{i}_me'] =  test[f'{i}_me'].fillna(train[f'{i}_me'].median())
    
train.drop('target', axis=1, inplace=True)
train.drop(var_categ, axis=1, inplace=True)
test.drop(var_categ, axis=1, inplace=True)

# %% [markdown]
# ## Load SE

# %%
se_train = pd.read_csv('/kaggle/input/interbank20/se_train.csv', index_col='key_value')
se_test = pd.read_csv('/kaggle/input/interbank20/se_test.csv', index_col='key_value')
# edad y cod_ubi tienen valores nulos con cerca de 1% cada uno

# %%
dict_ = {'sexo':'int32',
 'est_cvl':'int32',
 'sit_lab':'int32',
 'cod_ocu':'int32',
 'ctd_hijos':'int32',
 'flg_sin_email':'int32',
 'ctd_veh':'int32',
 'lgr_vot':'int32',
 'prv':'int32',
 'dto':'int32',
 'rgn':'int32',
 'tip_lvledu':'int32'}
se_train = se_train.astype(dict_)
se_test = se_test.astype(dict_)

# %%
### imputar datos faltantes en la base se_[train/test]
se_train['edad'].fillna(se_train['edad'].median(), inplace=True)
se_test['edad'].fillna(se_train['edad'].median(), inplace=True)
se_train['cod_ubi'].fillna(se_train['cod_ubi'].median(), inplace=True)
se_test['cod_ubi'].fillna(se_train['cod_ubi'].median(), inplace=True)

# %%
var_categ=['sit_lab','lgr_vot','sexo','rgn','tip_lvledu','flg_sin_email','prv','est_cvl','cod_ocu','dto']
# var_caunti=['edad','ctd_hijos','ctd_veh','cod_ubi']
se_train['target'] = y_train.loc[se_train.index]
for i in var_categ:
    me = se_train.groupby([i])['target'].mean().to_dict() 
    se_train[f'{i}_me'] =  se_train[i].map(me) 
    se_test[f'{i}_me'] =  se_test[i].map(me)
    ### imputar datos faltantes
    se_test[f'{i}_me'] =  se_test[f'{i}_me'].fillna(se_train[f'{i}_me'].median())
se_train.drop('target', axis=1, inplace=True)
se_train.drop(var_categ, axis=1, inplace=True)
se_test.drop(var_categ, axis=1, inplace=True)

# %%
train = train.join(se_train) ### Ojo 57 valores perdidos
test = test.join(se_test)
del se_train, se_test

# %%
### imputar valores faltantes
var_caunti = ['lgr_vot_me','sit_lab_me','cod_ubi','tip_lvledu_me','prv_me','rgn_me',
 'ctd_hijos','edad','cod_ocu_me','ctd_veh','est_cvl_me','dto_me','flg_sin_email_me','sexo_me']
for i in var_caunti:
    train[i] = train[i].fillna(train[i].median())
    test[i] = test[i].fillna(train[i].median())
gc.collect()
# Out:
# 24

# %% [markdown]
# ## Load Sunat

# %%
sunat_train = pd.read_csv('/kaggle/input/interbank20/sunat_train.csv')
sunat_test = pd.read_csv('/kaggle/input/interbank20/sunat_test.csv')

# %%
### eliminar registros duplicados
sunat_train.drop_duplicates(inplace=True)
sunat_test.drop_duplicates(inplace=True)

# %%
dict_ = dict(zip(list(sunat_train.dtypes[sunat_train.dtypes == int].index), ['int32']*len(sunat_train.dtypes[sunat_train.dtypes == int].index)))
sunat_train = sunat_train.astype(dict_)
sunat_test = sunat_test.astype(dict_)

# %%
import statistics as stat
import numpy as np
def calculate_mode(x):
    try:
        moda=stat.mode(x)
    except:
        moda=np.nan
    return moda
from tqdm.notebook import tqdm 
moda=lambda x: calculate_mode(x)
moda.__name__='mode'
agg_sunat = {'tipcontribuyente':['nunique',moda],
           'tippersona':['nunique',moda],
           'ciiu':['nunique', moda],
           'ubigeo':['nunique',moda],
           'condiciondomicilio':['nunique',moda],
           'estadocontribuyente':['nunique',moda],
           'codvia':['nunique',moda],
           'codzona':['nunique',moda],
           'contabilidad':['nunique',moda],
           'facturacion':['nunique',moda],
           'domiciliado':['nunique',moda],
           'comercioexterior':['nunique',moda],
           'cargorele':['nunique',moda],
           'codentidadtributo':['nunique',moda],
           'estadotributo':['nunique',moda],
           'fecalta':['mean','max', 'nunique'],
           'fecbaja':['mean','max', 'nunique'],
          }

# %%
sunat_train_ = sunat_train.groupby('key_value').agg(agg_sunat)
sunat_train_.columns = [i+'_'+j for i,j in sunat_train_.columns]
sunat_test_ = sunat_test.groupby('key_value').agg(agg_sunat)
sunat_test_.columns = [i+'_'+j for i,j in sunat_test_.columns]
del sunat_train, sunat_test

# %%
# var_categ = [i for i in sunat_train_.columns if 'mode' in i]
# for i in var_categ:
#     sunat_train_[i] = sunat_train_[i].fillna(sunat_train_[i].value_counts().index[0])
#     sunat_test_[i] = sunat_test_[i].fillna(sunat_train_[i].value_counts().index[0])

# %%
# sunat_train_['target'] = y_train.loc[sunat_train_.index]
# for i in var_categ:
#     me = sunat_train_.groupby([i])['target'].mean().to_dict() 
#     sunat_train_[f'{i}_me'] =  sunat_train_[i].map(me) 
#     sunat_test_[f'{i}_me'] =  sunat_test_[i].map(me)
#     ### imputar datos faltantes
#     sunat_test_[f'{i}_me'] =  sunat_test_[f'{i}_me'].fillna(sunat_train_[f'{i}_me'].median())
# sunat_train_.drop('target', axis=1, inplace=True)
# sunat_train_.drop(var_categ, axis=1, inplace=True)
# sunat_test_.drop(var_categ, axis=1, inplace=True)

# %%
train = train.join(sunat_train_)
test = test.join(sunat_test_)
train.shape, test.shape
# Out:
# ((358487, 442), (396666, 442))

# %%
test.isna().sum().sort_values().tail(35)
# Out:
# contabilidad_nunique           142863
# facturacion_nunique            142863
# fecbaja_nunique                142863
# codentidadtributo_nunique      142863
# comercioexterior_nunique       142863
# codvia_nunique                 142863
# domiciliado_nunique            142863
# estadocontribuyente_nunique    142863
# cargorele_nunique              142863
# condiciondomicilio_nunique     142863
# ubigeo_nunique                 142863
# estadotributo_nunique          142863
# ciiu_nunique                   142863
# tippersona_nunique             142863
# fecalta_nunique                142863
# tipcontribuyente_nunique       142863
# condiciondomicilio_mode        146526
# estadotributo_mode             150368
# codentidadtributo_mode         151505
# facturacion_mode               152047
# ubigeo_mode                    152647
# estadocontribuyente_mode       154535
# contabilidad_mode              155309
# comercioexterior_mode          156001
# codvia_mode                    156224
# codzona_mode                   157212
# tippersona_mode                161365
# domiciliado_mode               161430
# ciiu_mode                      163155
# cargorele_mode                 163351
# tipcontribuyente_mode          164486
# fecalta_mean                   167754
# fecalta_max                    167754
# fecbaja_mean                   357149
# fecbaja_max                    357149
# dtype: int64

# %%
# var_aux = list(train.isna().sum().sort_values().tail(34).index)
# var_categ = [i for i in var_aux if 'mode' in i]
# var_cuanti = [i for i in var_aux if 'mode' not in i]
# len(var_aux), len(var_categ), len(var_cuanti)

# for i in var_cuanti:
#     train[i] = train[i].fillna(train[i].median())
#     test[i] = test[i].fillna(train[i].median())
# for i in var_categ:
#     train[i] = train[i].fillna(train[i].value_counts().index[0])
#     test[i] = test[i].fillna(train[i].value_counts().index[0])

# %%
# var_cuanti = ['fecbaja_nunique', 'tipcontribuyente_mode_me', 'tippersona_mode_me', 'ciiu_mode_me',
# 'ubigeo_mode_me', 'condiciondomicilio_mode_me', 'estadocontribuyente_mode_me', 
# 'contabilidad_mode_me','codzona_mode_me', 'facturacion_mode_me', 'domiciliado_mode_me', 
# 'comercioexterior_mode_me', 'fecbaja_sum', 'cargorele_mode_me', 'codvia_mode_me', 
# 'fecalta_nunique', 'codvia_nunique', 'estadotributo_nunique', 'codentidadtributo_mode_me', 
# 'tipcontribuyente_nunique','tippersona_nunique', 'ciiu_nunique', 'ubigeo_nunique',
# 'condiciondomicilio_nunique','fecalta_sum', 'estadocontribuyente_nunique',
# 'contabilidad_nunique', 'facturacion_nunique','domiciliado_nunique', 'comercioexterior_nunique',
# 'cargorele_nunique', 'codentidadtributo_nunique', 'codzona_nunique', 'estadotributo_mode_me']
# for i in var_cuanti:
#     train[i] = train[i].fillna(train[i].median())
#     test[i] = test[i].fillna(train[i].median())

# %% [markdown]
# ## Training

# %%
keep_columns = set(train.columns).intersection(test.columns)
train=train[keep_columns].copy()
test=test[keep_columns].copy()
train.shape, test.shape
# Out:
# ((358487, 442), (396666, 442))

# %%
from catboost import CatBoostClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
import numpy as np
folds = [train.index[t] for t, v in KFold(5).split(train)]
test_probs = []
train_probs = []
fi = []
for i, idx in enumerate(folds):
    print("*"*10, i, "*"*10)
    Xt = train.loc[idx]
    yt = y_train.loc[Xt.index]

    Xv = train.drop(Xt.index)
    yv = y_train.loc[Xv.index]

    learner = CatBoostClassifier(n_estimators=1000,  eval_metric = 'AUC', max_depth = 6)
    learner.fit(Xt, yt,  early_stopping_rounds=10, 
                eval_set=[(Xt, yt), (Xv, yv)], verbose=50) # cat_features = var_categ_index,
    test_probs.append(pd.Series(learner.predict_proba(test)[:, -1], index=test.index, name="fold_" + str(i)))
    train_probs.append(pd.Series(learner.predict_proba(Xv)[:, -1], index=Xv.index, name="probs"))
    fi.append(pd.Series(learner.feature_importances_ / learner.feature_importances_.sum(), index=Xt.columns))
    gc.collect()
test_probs = pd.concat(test_probs, axis=1).mean(axis=1)
train_probs = pd.concat(train_probs)
fi = pd.concat(fi, axis=1).mean(axis=1)
print("*" * 21)
print("roc auc estimado: ", roc_auc_score(y_train, train_probs.loc[y_train.index]))
print("roc auc varianza: ", np.std([roc_auc_score(y_train.loc[folds[i]], train_probs.iloc[folds[i]]) for i in range(len(folds))]))
# Out:
# ********** 0 **********
# Learning rate set to 0.128212
# 0:	test: 0.7355943	test1: 0.7418072	best: 0.7418072 (0)	total: 353ms	remaining: 5m 52s
# 50:	test: 0.8259135	test1: 0.8238738	best: 0.8238738 (50)	total: 17.3s	remaining: 5m 22s
# 100:	test: 0.8346905	test1: 0.8313975	best: 0.8313975 (100)	total: 32.6s	remaining: 4m 50s
# 150:	test: 0.8414157	test1: 0.8362050	best: 0.8362050 (150)	total: 48.1s	remaining: 4m 30s
# 200:	test: 0.8464942	test1: 0.8393682	best: 0.8393682 (200)	total: 1m 3s	remaining: 4m 13s
# 250:	test: 0.8499092	test1: 0.8408360	best: 0.8408360 (250)	total: 1m 18s	remaining: 3m 55s
# 300:	test: 0.8528908	test1: 0.8417473	best: 0.8417473 (300)	total: 1m 32s	remaining: 3m 35s
# 350:	test: 0.8559071	test1: 0.8424663	best: 0.8424675 (349)	total: 1m 48s	remaining: 3m 19s
# 400:	test: 0.8587207	test1: 0.8429823	best: 0.8429823 (400)	total: 2m 3s	remaining: 3m 4s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.843361765
# bestIteration = 431
#
# Shrink model to first 432 iterations.
# ********** 1 **********
# Learning rate set to 0.128212
# 0:	test: 0.7288391	test1: 0.7272198	best: 0.7272198 (0)	total: 259ms	remaining: 4m 18s
# 50:	test: 0.8259890	test1: 0.8233702	best: 0.8233702 (50)	total: 16.5s	remaining: 5m 6s
# 100:	test: 0.8354080	test1: 0.8311611	best: 0.8311611 (100)	total: 31.9s	remaining: 4m 43s
# 150:	test: 0.8417916	test1: 0.8353764	best: 0.8353764 (150)	total: 47.4s	remaining: 4m 26s
# 200:	test: 0.8463341	test1: 0.8375991	best: 0.8375991 (200)	total: 1m 2s	remaining: 4m 6s
# 250:	test: 0.8501510	test1: 0.8388615	best: 0.8388615 (250)	total: 1m 16s	remaining: 3m 47s
# 300:	test: 0.8535072	test1: 0.8399236	best: 0.8399385 (299)	total: 1m 31s	remaining: 3m 31s
# 350:	test: 0.8562880	test1: 0.8407904	best: 0.8407904 (350)	total: 1m 46s	remaining: 3m 16s
# 400:	test: 0.8591615	test1: 0.8414104	best: 0.8414574 (398)	total: 2m 3s	remaining: 3m 4s
# 450:	test: 0.8617697	test1: 0.8420127	best: 0.8420127 (448)	total: 2m 18s	remaining: 2m 48s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.8420560798
# bestIteration = 451
#
# Shrink model to first 452 iterations.
# ********** 2 **********
# Learning rate set to 0.128212
# 0:	test: 0.7297279	test1: 0.7318776	best: 0.7318776 (0)	total: 273ms	remaining: 4m 32s
# 50:	test: 0.8255496	test1: 0.8262072	best: 0.8262072 (50)	total: 16.9s	remaining: 5m 14s
# 100:	test: 0.8346705	test1: 0.8332623	best: 0.8332623 (100)	total: 32.1s	remaining: 4m 45s
# 150:	test: 0.8414937	test1: 0.8379061	best: 0.8379061 (150)	total: 47.3s	remaining: 4m 25s
# 200:	test: 0.8460973	test1: 0.8402635	best: 0.8402635 (200)	total: 1m 1s	remaining: 4m 6s
# 250:	test: 0.8494716	test1: 0.8416222	best: 0.8416222 (250)	total: 1m 17s	remaining: 3m 49s
# 300:	test: 0.8528702	test1: 0.8428450	best: 0.8428450 (300)	total: 1m 31s	remaining: 3m 31s
# 350:	test: 0.8558361	test1: 0.8435604	best: 0.8435604 (350)	total: 1m 45s	remaining: 3m 14s
# 400:	test: 0.8586029	test1: 0.8441670	best: 0.8441670 (400)	total: 2m	remaining: 2m 59s
# 450:	test: 0.8612931	test1: 0.8447862	best: 0.8447981 (449)	total: 2m 15s	remaining: 2m 45s
# 500:	test: 0.8638397	test1: 0.8451791	best: 0.8452182 (497)	total: 2m 30s	remaining: 2m 30s
# 550:	test: 0.8661803	test1: 0.8455835	best: 0.8455835 (550)	total: 2m 44s	remaining: 2m 14s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.8459454831
# bestIteration = 587
#
# Shrink model to first 588 iterations.
# ********** 3 **********
# Learning rate set to 0.128212
# 0:	test: 0.7341078	test1: 0.7369510	best: 0.7369510 (0)	total: 263ms	remaining: 4m 23s
# 50:	test: 0.8257597	test1: 0.8255968	best: 0.8255968 (50)	total: 16.6s	remaining: 5m 9s
# 100:	test: 0.8349310	test1: 0.8328193	best: 0.8328193 (100)	total: 32.6s	remaining: 4m 49s
# 150:	test: 0.8413728	test1: 0.8368841	best: 0.8368841 (150)	total: 47.2s	remaining: 4m 25s
# 200:	test: 0.8459364	test1: 0.8393064	best: 0.8393064 (200)	total: 1m 2s	remaining: 4m 6s
# 250:	test: 0.8500392	test1: 0.8412417	best: 0.8412417 (250)	total: 1m 16s	remaining: 3m 49s
# 300:	test: 0.8533210	test1: 0.8422315	best: 0.8422315 (300)	total: 1m 31s	remaining: 3m 32s
# 350:	test: 0.8561860	test1: 0.8429090	best: 0.8429090 (350)	total: 1m 45s	remaining: 3m 14s
# 400:	test: 0.8586454	test1: 0.8434903	best: 0.8435397 (397)	total: 2m	remaining: 2m 59s
# 450:	test: 0.8612499	test1: 0.8438263	best: 0.8438339 (447)	total: 2m 14s	remaining: 2m 43s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.844099209
# bestIteration = 475
#
# Shrink model to first 476 iterations.
# ********** 4 **********
# Learning rate set to 0.128212
# 0:	test: 0.7532809	test1: 0.7460819	best: 0.7460819 (0)	total: 331ms	remaining: 5m 30s
# 50:	test: 0.8271505	test1: 0.8184259	best: 0.8184259 (50)	total: 16s	remaining: 4m 57s
# 100:	test: 0.8365579	test1: 0.8256731	best: 0.8256731 (100)	total: 31.8s	remaining: 4m 43s
# 150:	test: 0.8430828	test1: 0.8296875	best: 0.8296875 (150)	total: 47.3s	remaining: 4m 25s
# 200:	test: 0.8480998	test1: 0.8323378	best: 0.8323378 (200)	total: 1m 2s	remaining: 4m 8s
# 250:	test: 0.8520570	test1: 0.8338473	best: 0.8338473 (250)	total: 1m 17s	remaining: 3m 50s
# 300:	test: 0.8552714	test1: 0.8350197	best: 0.8350216 (297)	total: 1m 32s	remaining: 3m 34s
# 350:	test: 0.8580006	test1: 0.8358920	best: 0.8358920 (350)	total: 1m 47s	remaining: 3m 18s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.8361979734
# bestIteration = 387
#
# Shrink model to first 388 iterations.
# *********************
# roc auc estimado:  0.842367750765048
# roc auc varianza:  0.0008145433751046322

# %%
# roc auc estimado:  0.8424687425470667
# roc auc varianza:  0.0007821982745068659

# %%
fi.sort_values(ascending=False).head(50)
# Out:
# dto_me                                            0.057496
# COD_CLASIFICACION_DEUDOR_sum_ult1mes              0.032961
# COD_CLASIFICACION_DEUDOR_max_ult1mes              0.028900
# tip_lvledu_me                                     0.027554
# cod_instit_financiera_mode_ult1mes_me             0.027523
# RIESGO_DIRECTO_-1_saldo_ult12meses                0.023347
# tipo_credito_12_saldo_ult1meses                   0.022829
# edad                                              0.021637
# RIESGO_DIRECTO_1_saldo_ult1meses                  0.021604
# cod_instit_financiera_mode_ult12mes_me            0.021485
# tipo_credito_11_saldo_ult1meses                   0.021073
# COD_CLASIFICACION_DEUDOR_sum_ult2mes              0.018194
# tipo_credito_11_saldo_ult12meses                  0.018094
# cod_instit_financiera_nunique_ult1mes             0.015185
# COD_CLASIFICACION_DEUDOR_nunique_ult1mes          0.014191
# flg_sin_email_me                                  0.013937
# saldo_mean_ult1mes                                0.013798
# sexo_me                                           0.013192
# COD_CLASIFICACION_DEUDOR_0_saldo_ult12meses       0.013188
# saldo_mean_ult12mes                               0.012699
# COD_CLASIFICACION_DEUDOR_0_saldo_ult1meses        0.012680
# RIESGO_DIRECTO_-1_saldo_ult1meses                 0.012067
# cod_instit_financiera_mode_ult2mes_me             0.011347
# RIESGO_DIRECTO_1_saldo_ult12meses                 0.011232
# sit_lab_me                                        0.010945
# condicion_max_ult1mes                             0.009374
# tipo_credito_12_saldo_ult2meses                   0.008866
# cod_ubi                                           0.008707
# cod_instit_financiera_mode_ult6mes_me             0.008597
# cod_instit_financiera_mode_ult5mes_me             0.008526
# saldo_min_ult1mes                                 0.008346
# cod_instit_financiera_mode_ult4mes_me             0.008164
# RIESGO_DIRECTO_-1_saldo_ult2meses                 0.007945
# COD_CLASIFICACION_DEUDOR_5_condicion_ult1meses    0.007823
# RIESGO_DIRECTO_1_saldo_ult2meses                  0.007744
# COD_CLASIFICACION_DEUDOR_0_saldo_ult2meses        0.007231
# ctd_veh                                           0.006924
# PRODUCTO_nunique_ult1mes                          0.006645
# tipo_credito_11_saldo_ult2meses                   0.006404
# saldo_mean_ult2mes                                0.006146
# RIESGO_DIRECTO_1_condicion_ult12meses             0.006015
# prv_me                                            0.005902
# RIESGO_DIRECTO_1_condicion_ult2meses              0.005613
# lgr_vot_me                                        0.005570
# saldo_max_ult1mes                                 0.005308
# cod_instit_financiera_mode_ult3mes_me             0.005267
# saldo_std_ult1mes                                 0.005166
# condicion_std_ult1mes                             0.005074
# tipo_credito_12_saldo_ult12meses                  0.005039
# estadocontribuyente_mode                          0.004944
# dtype: float64

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
import numpy as np
folds = [train.index[t] for t, v in KFold(5).split(train)]
test_probs = []
train_probs = []
fi = []
for i, idx in enumerate(folds):
    print("*"*10, i, "*"*10)
    Xt = train.loc[idx]
    yt = y_train.loc[Xt.index]

    Xv = train.drop(Xt.index)
    yv = y_train.loc[Xv.index]

    learner = LGBMClassifier(n_estimators=1000, max_depth = 6, boosting_type='gbdt', min_child_samples=1000)
    learner.fit(Xt, yt,  early_stopping_rounds=10, eval_metric="auc",
                eval_set=[(Xt, yt), (Xv, yv)], verbose=50)
    test_probs.append(pd.Series(learner.predict_proba(test)[:, -1], index=test.index, name="fold_" + str(i)))
    train_probs.append(pd.Series(learner.predict_proba(Xv)[:, -1], index=Xv.index, name="probs"))
    fi.append(pd.Series(learner.feature_importances_ / learner.feature_importances_.sum(), index=Xt.columns))

test_probs = pd.concat(test_probs, axis=1).mean(axis=1)
train_probs = pd.concat(train_probs)
fi = pd.concat(fi, axis=1).mean(axis=1)
print("*" * 21)
print("roc auc estimado: ", roc_auc_score(y_train, train_probs.loc[y_train.index]))
print("roc auc varianza: ", np.std([roc_auc_score(y_train.loc[folds[i]], train_probs.iloc[folds[i]]) for i in range(len(folds))]))
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# ********** 0 **********
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Training until validation scores don't improve for 10 rounds
# [50]	training's auc: 0.835743	training's binary_logloss: 0.307517	valid_1's auc: 0.829301	valid_1's binary_logloss: 0.312395
# [100]	training's auc: 0.847379	training's binary_logloss: 0.298746	valid_1's auc: 0.837608	valid_1's binary_logloss: 0.306282
# [150]	training's auc: 0.853192	training's binary_logloss: 0.294163	valid_1's auc: 0.84071	valid_1's binary_logloss: 0.303945
# [200]	training's auc: 0.858085	training's binary_logloss: 0.290571	valid_1's auc: 0.842665	valid_1's binary_logloss: 0.302523
# [250]	training's auc: 0.861893	training's binary_logloss: 0.28765	valid_1's auc: 0.843774	valid_1's binary_logloss: 0.301745
# [300]	training's auc: 0.865831	training's binary_logloss: 0.284723	valid_1's auc: 0.844798	valid_1's binary_logloss: 0.301038
# [350]	training's auc: 0.868886	training's binary_logloss: 0.282322	valid_1's auc: 0.845488	valid_1's binary_logloss: 0.30054
# [400]	training's auc: 0.871052	training's binary_logloss: 0.280591	valid_1's auc: 0.845618	valid_1's binary_logloss: 0.300427
# [450]	training's auc: 0.873816	training's binary_logloss: 0.278394	valid_1's auc: 0.845901	valid_1's binary_logloss: 0.300275
# Early stopping, best iteration is:
# [453]	training's auc: 0.874089	training's binary_logloss: 0.278203	valid_1's auc: 0.845934	valid_1's binary_logloss: 0.300259
# ********** 1 **********
# Training until validation scores don't improve for 10 rounds
# [50]	training's auc: 0.836039	training's binary_logloss: 0.307472	valid_1's auc: 0.829161	valid_1's binary_logloss: 0.312807
# [100]	training's auc: 0.847293	training's binary_logloss: 0.298986	valid_1's auc: 0.836453	valid_1's binary_logloss: 0.307105
# [150]	training's auc: 0.85421	training's binary_logloss: 0.293813	valid_1's auc: 0.840191	valid_1's binary_logloss: 0.304371
# [200]	training's auc: 0.858785	training's binary_logloss: 0.290312	valid_1's auc: 0.841775	valid_1's binary_logloss: 0.303142
# [250]	training's auc: 0.862595	training's binary_logloss: 0.287445	valid_1's auc: 0.8427	valid_1's binary_logloss: 0.302377
# [300]	training's auc: 0.865756	training's binary_logloss: 0.284982	valid_1's auc: 0.843353	valid_1's binary_logloss: 0.301753
# [350]	training's auc: 0.868843	training's binary_logloss: 0.282596	valid_1's auc: 0.843818	valid_1's binary_logloss: 0.301351
# [400]	training's auc: 0.871898	training's binary_logloss: 0.280302	valid_1's auc: 0.844222	valid_1's binary_logloss: 0.300958
# [450]	training's auc: 0.873793	training's binary_logloss: 0.278776	valid_1's auc: 0.844396	valid_1's binary_logloss: 0.300813
# Early stopping, best iteration is:
# [483]	training's auc: 0.875141	training's binary_logloss: 0.277683	valid_1's auc: 0.84463	valid_1's binary_logloss: 0.300631
# ********** 2 **********
# Training until validation scores don't improve for 10 rounds
# [50]	training's auc: 0.836004	training's binary_logloss: 0.307839	valid_1's auc: 0.832515	valid_1's binary_logloss: 0.310056
# [100]	training's auc: 0.846936	training's binary_logloss: 0.299498	valid_1's auc: 0.839304	valid_1's binary_logloss: 0.304465
# [150]	training's auc: 0.85324	training's binary_logloss: 0.29476	valid_1's auc: 0.842096	valid_1's binary_logloss: 0.302039
# [200]	training's auc: 0.85783	training's binary_logloss: 0.291283	valid_1's auc: 0.843659	valid_1's binary_logloss: 0.300733
# [250]	training's auc: 0.861843	training's binary_logloss: 0.288253	valid_1's auc: 0.844877	valid_1's binary_logloss: 0.299793
# [300]	training's auc: 0.865373	training's binary_logloss: 0.285577	valid_1's auc: 0.845325	valid_1's binary_logloss: 0.299298
# Early stopping, best iteration is:
# [331]	training's auc: 0.867096	training's binary_logloss: 0.284256	valid_1's auc: 0.845558	valid_1's binary_logloss: 0.29908
# ********** 3 **********
# Training until validation scores don't improve for 10 rounds
# [50]	training's auc: 0.835592	training's binary_logloss: 0.308075	valid_1's auc: 0.829366	valid_1's binary_logloss: 0.311058
# [100]	training's auc: 0.847067	training's binary_logloss: 0.299446	valid_1's auc: 0.837571	valid_1's binary_logloss: 0.304756
# [150]	training's auc: 0.853669	training's binary_logloss: 0.294437	valid_1's auc: 0.840792	valid_1's binary_logloss: 0.30227
# [200]	training's auc: 0.858341	training's binary_logloss: 0.290927	valid_1's auc: 0.842506	valid_1's binary_logloss: 0.300926
# [250]	training's auc: 0.861604	training's binary_logloss: 0.2884	valid_1's auc: 0.843456	valid_1's binary_logloss: 0.300154
# [300]	training's auc: 0.864825	training's binary_logloss: 0.285911	valid_1's auc: 0.844338	valid_1's binary_logloss: 0.29948
# [350]	training's auc: 0.867794	training's binary_logloss: 0.283562	valid_1's auc: 0.844908	valid_1's binary_logloss: 0.298995
# [400]	training's auc: 0.870184	training's binary_logloss: 0.281651	valid_1's auc: 0.845149	valid_1's binary_logloss: 0.298776
# [450]	training's auc: 0.873178	training's binary_logloss: 0.279349	valid_1's auc: 0.845418	valid_1's binary_logloss: 0.298599
# Early stopping, best iteration is:
# [446]	training's auc: 0.872903	training's binary_logloss: 0.279562	valid_1's auc: 0.845465	valid_1's binary_logloss: 0.29858
# ********** 4 **********
# Training until validation scores don't improve for 10 rounds
# [50]	training's auc: 0.837217	training's binary_logloss: 0.307424	valid_1's auc: 0.823971	valid_1's binary_logloss: 0.312614
# [100]	training's auc: 0.848607	training's binary_logloss: 0.298811	valid_1's auc: 0.83099	valid_1's binary_logloss: 0.307255
# [150]	training's auc: 0.855444	training's binary_logloss: 0.293705	valid_1's auc: 0.834016	valid_1's binary_logloss: 0.304945
# [200]	training's auc: 0.860124	training's binary_logloss: 0.290077	valid_1's auc: 0.835669	valid_1's binary_logloss: 0.303816
# [250]	training's auc: 0.864133	training's binary_logloss: 0.287078	valid_1's auc: 0.836923	valid_1's binary_logloss: 0.302941
# [300]	training's auc: 0.867189	training's binary_logloss: 0.284671	valid_1's auc: 0.837644	valid_1's binary_logloss: 0.302384
# [350]	training's auc: 0.870089	training's binary_logloss: 0.282389	valid_1's auc: 0.838014	valid_1's binary_logloss: 0.302113
# [400]	training's auc: 0.872982	training's binary_logloss: 0.280078	valid_1's auc: 0.838639	valid_1's binary_logloss: 0.301687
# Early stopping, best iteration is:
# [400]	training's auc: 0.872982	training's binary_logloss: 0.280078	valid_1's auc: 0.838639	valid_1's binary_logloss: 0.301687
# *********************
# roc auc estimado:  0.8440691439563721
# roc auc varianza:  0.0006680432360303134

# %%
# roc auc estimado:  0.8440075260735874
# roc auc varianza:  0.0006285760199721268

# %%
fi.sort_values(ascending=False).head(50)
# Out:
# dto_me                                            0.028133
# saldo_mean_ult12mes                               0.022359
# edad                                              0.022353
# RIESGO_DIRECTO_-1_saldo_ult12meses                0.022119
# RIESGO_DIRECTO_1_saldo_ult1meses                  0.020499
# cod_ubi                                           0.018854
# tipo_credito_11_saldo_ult12meses                  0.018470
# RIESGO_DIRECTO_1_saldo_ult12meses                 0.016909
# tipo_credito_11_saldo_ult1meses                   0.016395
# cod_instit_financiera_mode_ult1mes_me             0.015819
# RIESGO_DIRECTO_-1_saldo_ult1meses                 0.015436
# cod_instit_financiera_mode_ult12mes_me            0.015425
# COD_CLASIFICACION_DEUDOR_0_saldo_ult12meses       0.014059
# saldo_min_ult1mes                                 0.013639
# ubigeo_mode                                       0.013194
# fecalta_mean                                      0.012688
# tipo_credito_12_saldo_ult12meses                  0.012310
# tipo_credito_12_saldo_ult1meses                   0.011666
# ciiu_mode                                         0.011507
# tip_lvledu_me                                     0.011247
# saldo_mean_ult1mes                                0.010624
# RIESGO_DIRECTO_1_saldo_ult2meses                  0.010451
# prv_me                                            0.010211
# RIESGO_DIRECTO_-1_saldo_ult2meses                 0.009704
# saldo_max_ult1mes                                 0.009361
# COD_CLASIFICACION_DEUDOR_0_saldo_ult1meses        0.009067
# saldo_max_ult12mes                                0.008856
# RIESGO_DIRECTO_1_saldo_ult3meses                  0.008568
# saldo_std_ult1mes                                 0.008496
# sexo_me                                           0.008199
# lgr_vot_me                                        0.007789
# estadocontribuyente_mode                          0.007771
# cod_instit_financiera_mode_ult2mes_me             0.007543
# flg_sin_email_me                                  0.007239
# cod_instit_financiera_mode_ult3mes_me             0.007135
# RIESGO_DIRECTO_1_condicion_ult12meses             0.007086
# cod_instit_financiera_nunique_ult1mes             0.006910
# cod_ocu_me                                        0.006826
# tipo_credito_11_saldo_ult2meses                   0.006627
# saldo_mean_ult2mes                                0.006601
# tipo_credito_10_saldo_ult1meses                   0.006507
# sit_lab_me                                        0.006478
# COD_CLASIFICACION_DEUDOR_5_condicion_ult1meses    0.006451
# saldo_std_ult12mes                                0.006316
# tipo_credito_10_saldo_ult12meses                  0.006313
# fecalta_max                                       0.005975
# COD_CLASIFICACION_DEUDOR_0_saldo_ult2meses        0.005935
# codzona_mode                                      0.005710
# PRODUCTO_nunique_ult2mes                          0.005660
# cod_instit_financiera_mode_ult6mes_me             0.005608
# dtype: float64

# %%
# from catboost import CatBoostClassifier
# from sklearn.model_selection import ParameterGrid
# from sklearn.metrics import roc_auc_score
# from sklearn.model_selection import KFold
# folds = [train.index[t] for t, v in KFold(5).split(train)]
# params = ParameterGrid({"min_child_samples": [150, 250, 500, 1000], "boosting_type": ["Plain"]}) # Ordered
# best_score = 0
# best_probs = []
# for param in params:
#     test_probs = []
#     train_probs = []
#     p  = "///".join([f"{k}={v}" for k, v in param.items()])
#     print("*"*10, p, "*"*10)
#     for i, idx in enumerate(folds):
#         Xt = train.loc[idx]
#         yt = y_train.loc[Xt.index]

#         Xv = train.drop(Xt.index)
#         yv = y_train.loc[Xv.index]

#         learner = CatBoostClassifier(n_estimators=1000,  eval_metric = 'AUC', **param)
#         learner.fit(Xt, yt,  early_stopping_rounds=10, 
#                     eval_set=[(Xt, yt), (Xv, yv)], verbose=100) 

#         test_probs.append(pd.Series(learner.predict_proba(test)[:, -1], index=test.index, name="fold_" + str(i)))
#         train_probs.append(pd.Series(learner.predict_proba(Xv)[:, -1], index=Xv.index, name="probs"))

#     test_probs = pd.concat(test_probs, axis=1).mean(axis=1)
#     train_probs = pd.concat(train_probs)
#     score = roc_auc_score(y_train, train_probs.loc[y_train.index])
#     print(f"roc auc estimado para {p}: {score}")
#     if score > best_score:
#         print("*"*10, f"{p} es el nuevo mejor modelo", "*"*10)
#         best_score = score
#         best_probs = test_probs

# %%
# roc auc estimado para boosting_type=Ordered///min_child_samples=150: 0.839757753147848
# ********** boosting_type=Ordered///min_child_samples=150 es el nuevo mejor modelo **********

# roc auc estimado para boosting_type=Plain///min_child_samples=150: 0.8407009481328498
# ********** boosting_type=Plain///min_child_samples=150 es el nuevo mejor modelo **********

# roc auc estimado para boosting_type=Plain///min_child_samples=250: 0.8407009481328498

# roc auc estimado para boosting_type=Plain///min_child_samples=500: 0.8407009481328498

# roc auc estimado para boosting_type=Plain///min_child_samples=1000: 0.8407009481328498

# %%
# from sklearn.model_selection import ParameterGrid
# folds = [train.index[t] for t, v in KFold(5).split(train)]

# params = ParameterGrid({"min_child_samples": [150, 250, 500, 1000], "boosting_type": ["gbdt", "goss"]})
# best_score = 0
# best_probs = []
# for param in params:
#     test_probs = []
#     train_probs = []
#     p  = "///".join([f"{k}={v}" for k, v in param.items()])
#     print("*"*10, p, "*"*10)
#     for i, idx in enumerate(folds):
#         Xt = train.loc[idx]
#         yt = y_train.loc[Xt.index]

#         Xv = train.drop(Xt.index)
#         yv = y_train.loc[Xv.index]

#         learner = LGBMClassifier(n_estimators=1000, **param)
#         learner.fit(Xt, yt,  early_stopping_rounds=10, eval_metric="auc",
#                     eval_set=[(Xt, yt), (Xv, yv)], verbose=False)
#         test_probs.append(pd.Series(learner.predict_proba(test)[:, -1], index=test.index, name="fold_" + str(i)))
#         train_probs.append(pd.Series(learner.predict_proba(Xv)[:, -1], index=Xv.index, name="probs"))

#     test_probs = pd.concat(test_probs, axis=1).mean(axis=1)
#     train_probs = pd.concat(train_probs)
#     score = roc_auc_score(y_train, train_probs.loc[y_train.index])
#     print(f"roc auc estimado para {p}: {score}")
#     if score > best_score:
#         print("*"*10, f"{p} es el nuevo mejor modelo", "*"*10)
#         best_score = score
#         best_probs = test_probs

# %%
# roc auc estimado:  0.860778375567941  # roc auc estimado:  0.8287296558597061 benchmark

# roc auc estimado:  0.8235666881996343 solo considerando rcc, inputando datos categoricos. con 4 mes
# roc auc varianza:  0.0005453571957666847

# roc auc estimado:  0.8236751116856392 solo considerando rcc, inputando datos categoricos. con 6 mes
# roc auc varianza:  0.0007266775450365375

# roc auc estimado:  0.8240426706542976 solo considerando rcc, inputando datos categoricos. con 6 mes. Mean_encoding
# roc auc varianza:  0.0006480438484228306

# roc auc estimado:  0.8358995025496325   solo considerando rcc, inputando datos categoricos. con 6 mes. Mean_encoding
# roc auc varianza:  0.000799546878111712  y incluyendo se sin imputar datos

# roc auc estimado:  0.8362318848230975    solo considerando rcc, inputando datos categoricos. con 6 mes. Mean_encoding
# roc auc varianza:  0.0006670589830583723 y incluyendo la base se imputando edad y cod_ubi

# roc auc estimado:  0.8357779560666587  solo considerando rcc, inputando datos categoricos. con 6 mes. Mean_encoding
# roc auc varianza:  0.0008281941487650447 y incluyendo la base se imputando edad y cod_ubi. y en base final 

# roc auc estimado:  0.8386997825126665  solo considerando rcc, inputando datos categoricos. con 6 mes. Mean_encoding
# roc auc varianza:  0.0007378701891037694 y incluyendo la base se imputando edad y cod_ubi con Mean Encoding

# roc auc estimado:  0.8390378213410135 solo considerando rcc, inputando datos categoricos. con 6 mes. Mean_encoding
# roc auc varianza:  0.0007879483415566218 y incluyendo la base se imputando edad y cod_ubi con Mean Encoding. Impuntando la base final
#### 0.83049 es el score en el leaderboard

# roc auc estimado:  0.860778375567941 solo considerando rcc, inputando datos categoricos. con 6 mes. Mean_encoding
# roc auc varianza:  0.0007522563589463705 y incluyendo la base se imputando edad y cod_ubi con Mean Encoding. 
#                                         Add censo sin imputar datos
#### Hay un sobreajuste de los datos (0.81290)

# roc auc estimado:  0.8601038804961594 solo considerando rcc, inputando datos categoricos. con 6 mes. Mean_encoding
# roc auc varianza:  0.0007408029176933889 y incluyendo la base se imputando edad y cod_ubi con Mean Encoding. 
#                                         Add censo. Inputando datos en la base final 
####  Hay un sobreajuste de los datos (0.81335)

# roc auc estimado:  0.8403745150148406 solo considerando rcc, inputando datos categoricos. con 6 mes. Mean_encoding
# roc auc varianza:  0.0007145134831505686 y incluyendo la base se imputando edad y cod_ubi con Mean Encoding.
#                                         Add sunat, sin imputar datos 
#### 0.83169 es el score en el leaderboard

# roc auc estimado:  0.8404409620195707 solo considerando rcc, inputando datos categoricos. con 6 mes. Mean_encoding
# roc auc varianza:  0.0007187836690898979 y incluyendo la base se imputando edad y cod_ubi con Mean Encoding.
#                                         Add sunat, imputando datos en la base final

# roc auc estimado:  0.8424448270443908 solo considerando rcc, inputando datos categoricos. con 6 mes. Mean_encoding
# roc auc varianza:  0.0006541668625712339 y incluyendo la base se imputando edad y cod_ubi con Mean Encoding.
#                                         Add sunat con Mean Encoding. Inputando en la base final
#### 0.82922 es el score en el leaderboard

# roc auc estimado:  0.8400602964442501 solo considerando rcc, inputando datos categoricos. con 12 mes. Mean_encoding
# roc auc varianza:  0.0007915113545841123 y incluyendo la base se imputando edad y cod_ubi con Mean Encoding.
#                                         Add sunat, sin imputar datos 

# roc auc estimado:  0.8404655548713938 solo considerando rcc, inputando datos categoricos. con 12 mes. Mean_encoding
# roc auc varianza:  0.0007525289304731753 y incluyendo la base se imputando edad y cod_ubi con Mean Encoding.
#                                         Add sunat, sin imputar datos y eliminando COD_CLASIFICACION_DEUDOR_sum_ult2mes

# roc auc estimado:  0.835370939961718 solo considerando rcc, inputando datos categoricos. con 12 mes. Mean_encoding
# roc auc varianza:  0.0007997947306923314 y incluyendo la base se imputando edad y cod_ubi con Mean Encoding.
#                                         Add sunat, sin imputar datos y eliminando COD_CLASIFICACION_DEUDOR_sum_ult2mes
#                                          eliminando variables correlacionadas con 211 variables

# roc auc estimado:  **************** solo considerando rcc, inputando datos categoricos. con 6 mes. Mean_encoding
# roc auc varianza:  **************** y incluyendo la base se imputando edad y cod_ubi con Mean Encoding.
#                                         Add sunat, sin imputar datos. Con modelo ensamblado de CatBoost y LightGBM
#### 0.83292 score en el leaderboard

# %%
from catboost import CatBoostClassifier
learner_ = CatBoostClassifier(n_estimators=1000, eval_metric = 'AUC', max_depth = 6)
learner_.fit(train, y_train,  early_stopping_rounds=10, verbose = 50)
# Out:
# Learning rate set to 0.126968
# 0:	total: 369ms	remaining: 6m 8s
# 50:	total: 18s	remaining: 5m 34s
# 100:	total: 36.2s	remaining: 5m 22s
# 150:	total: 53s	remaining: 4m 58s
# 200:	total: 1m 9s	remaining: 4m 35s
# 250:	total: 1m 24s	remaining: 4m 13s
# 300:	total: 1m 41s	remaining: 3m 54s
# 350:	total: 1m 57s	remaining: 3m 36s
# 400:	total: 2m 12s	remaining: 3m 18s
# 450:	total: 2m 28s	remaining: 3m 1s
# 500:	total: 2m 44s	remaining: 2m 44s
# 550:	total: 3m 2s	remaining: 2m 28s
# 600:	total: 3m 19s	remaining: 2m 12s
# 650:	total: 3m 35s	remaining: 1m 55s
# 700:	total: 3m 52s	remaining: 1m 39s
# 750:	total: 4m 8s	remaining: 1m 22s
# 800:	total: 4m 25s	remaining: 1m 5s
# 850:	total: 4m 41s	remaining: 49.3s
# 900:	total: 4m 57s	remaining: 32.7s
# 950:	total: 5m 12s	remaining: 16.1s
# 999:	total: 5m 29s	remaining: 0us

# %%
from lightgbm import LGBMClassifier
learner2 = LGBMClassifier(n_estimators=1000, max_depth=6, boosting_type='gbdt', min_child_samples=1000)
learner2.fit(train, y_train, eval_metric="auc", verbose=50)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# LGBMClassifier(max_depth=6, min_child_samples=1000, n_estimators=1000)

# %%
test_probs_ = pd.Series(learner_.predict_proba(test)[:, -1], index=test.index, name="target")
test_probs2 = pd.Series(learner2.predict_proba(test)[:, -1], index=test.index, name="target")
test_probs_mean = test_probs_*0.5 + test_probs2*0.5
test_probs_mean.name = 'target'

# %%
test_probs_mean.name = "target"
test_probs_mean.to_cs("test38.csv")

# %% [markdown]
# <a href = 'test38.csv'>Download csv</a>

# %%
#### final

# %%
learner_ = CatBoostClassifier(n_estimators=1000, eval_metric = 'AUC', max_depth = 8)
learner_.fit(train, y_train,  early_stopping_rounds=10, verbose = 50)

# %%
fi_ = pd.Series(learner_.feature_importances_ / learner_.feature_importances_.sum(), index=train.columns)
fi_.sort_values(ascending=False).head(50)

# %%
learner_ = learner2

# %%
test_probs_ = pd.Series(learner_.predict_proba(test)[:, -1], index=test.index, name="target")
test_probs_.shape

# %%
test_probs_.name = "target"
test_probs_.to_csv("test30.csv")

# %% [markdown]
# <a href=test30.csv>Download csv</a>
